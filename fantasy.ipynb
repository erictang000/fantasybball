# %%
import numpy as np
import pandas as pd
import logging
import json
import sys
import selenium
import urllib.parse as urlparse
from operator import itemgetter
import time
import matplotlib.pyplot as plt
import matplotlib.style as style
import seaborn as sns
import requests
from bs4 import BeautifulSoup
from flask import Flask, render_template, request, redirect, url_for, abort
import requests
import copy
import config
import datetime
from IPython.display import display, HTML


# Create the Flask application.
app = Flask(__name__)
app.logger.setLevel(logging.INFO)
app.config.from_object(config.ProductionConfig)
from selenium.webdriver import Chrome
import time

# %%
def call_espn_api(league_id):
    app.logger.info('%s - Calling ESPN API', league_id)
    url = ("https://fantasy.espn.com/apis/v3/games/fba/seasons/2020/segments/0/leagues/{}?&view=mMatchupScore&view=mPendingTransactions&view=mPositionalRatings&view=mRoster&view=mTeam&view=modular)".format(league_id))
    try:
        r = requests.get(url)
    except requests.exceptions.RequestException as ex:
        app.logger.error('%s - Could not make ESPN API call', league_id, ex)
        abort(500)
        sys.exit('Could not make ESPN API call.')
    data = r.json()
    return data

# %%
class Player:
    def __init__(self, name):
        self.name = name
        self.fga = 1.0
        self.fgm = 0
        self.fgp = self.fgm / self.fga
        self.fta = 1.0
        self.ftm = 0
        self.ftp = self.ftm / self.fta
        self.pts = 0
        self.ast = 0
        self.rbs = 0
        self.tov = 0
        self.m3s = 0
        self.stl = 0
        self.blk = 0
    def __str__(self):
        return self.name + " pts/reb/ast: " + format(self.pts ,'.2f') + "/" + format(self.rbs ,'.2f') + "/" + format(self.ast ,'.2f') + " stl/blk/tov: " + format(self.stl ,'.2f') + "/" + format(self.blk ,'.2f') + "/" + format(self.tov ,'.2f') + "/" + " fg%/ft%/3pm: " + format(self.fgp ,'.2f') + "/" + format(self.ftp ,'.2f') + "/" + format(self.m3s ,'.2f')

# %%
data["teams"]
# Out:
# [{'abbrev': 'SHAR',
#   'currentProjectedRank': 0,
#   'divisionId': 0,
#   'draftDayProjectedRank': 0,
#   'draftStrategy': {},
#   'id': 1,
#   'isActive': False,
#   'location': 'The',
#   'logo': 'https://g.espncdn.com/lm-static/logo-packs/core/DIS_Avengers_EndGame/DIS_Avengers_EndGame_Thanos.svg',
#   'logoType': 'VECTOR',
#   'nickname': 'Splash Brothers',
#   'owners': ['{1E410FC9-2315-4D88-8348-CA691BE9EC38}'],
#   'playoffSeed': 5,
#   'points': 0.0,
#   'pointsAdjusted': 0.0,
#   'pointsDelta': 0.0,
#   'primaryOwner': '{1E410FC9-2315-4D88-8348-CA691BE9EC38}',
#   'rankCalculatedFinal': 0,
#   'rankFinal': 0,
#   'record': {'away': {'gamesBack': 0.0,
#     'losses': 2,
#     'percentage': 0.7777777777777778,
#     'pointsAgainst': 0.0,
#     'pointsFor': 0.0,
#     'streakLength': 3,
#     'streakType': 'WIN',
#     'ties': 0,
#     'wins': 7},
#    'division': {'gamesBack': 3.0,
#     'losses': 5,
#     'percentage': 0.375,
#     'pointsAgainst': 0.0,
#     'pointsFor': 0.0,
#     'streakLength': 2,
#     'streakType': 'LOSS',
#     'ties': 0,
#     'wins': 3},
#    'home': {'gamesBack': 0.0,
#     'losses': 7,
#     'percentage': 0.3,
#     'pointsAgainst': 0.0,
#     'pointsFor': 0.0,
#     'streakLength': 1,
#     'streakType': 'WIN',
#     'ties': 0,
#     'wins': 3},
#    'overall': {'gamesBack': 3.5,
#     'losses': 9,
#     'percentage': 0.5263157894736842,
#     'pointsAgainst': 0.0,
#     'pointsFor': 0.0,
#     'streakLength': 2,
#     'streakType': 'WIN',
#     'ties': 0,
#     'wins': 10}},
#   'roster': {'entries': [{'acquisitionDate': 1571625036717,
#      'acquisitionType': 'DRAFT',
#      'injuryStatus': 'NORMAL',
#      'lineupSlotId': 4,
#      'pendingTransactionIds': None,
#      'playerId': 3112335,
#      'playerPoolEntry': {'id': 3112335,
#       'keeperValue': 0,
#       'keeperValueFuture': 1,
#       'lineupLocked': False,
#       'onTeamId': 1,
#       'player': {'active': True,
#        'defaultPositionId': 5,
#        'draftRanksByRankType': {'STANDARD': {'auctionValue': 62,
#          'published': False,
#          'rank': 4,
#          'rankSourceId': 0,
#          'rankType': 'STANDARD',
#          'slotId': 0}},
#        'droppable': False,
#        'eligibleSlots': [4, 9, 10, 11, 12, 13],
#        'firstName': 'Nikola',
#        'fullName': 'Nikola Jokic',
#        'id': 3112335,
#        'injured': False,
#        'injuryStatus': 'ACTIVE',
#        'lastName': 'Jokic',
#        'lastNewsDate': 1583985673000,
#        'lastVideoDate': 1583974338000,
#        'ownership': {'auctionValueAverage': 54.46120689655172,
#         'averageDraftPosition': 6.444156685011331,
#         'percentChange': -0.47573873614429374,
#         'percentOwned': 99.47089947089947,
#         'percentStarted': 81.48148148148148},
#        'proTeamId': 7,
#        'seasonOutlook': "Jokic burst onto the MVP scene last season as the most consistent triple-double threat this side of Russell Westbrook, and at 24 he should still be improving going into this season. He doesn't get quite enough assists to average a triple-double, but if he is in that neighborhood while averaging 20/10 and posting strong peripherals in every category including 3-pointers and shooting percentages. He's a legitimate top-5 draft pick with a weak but defendable case for No. 1.",
#        'stats': [{'externalId': '2020',
#          'id': '012020',
#          'proTeamId': 0,
#          'scoringPeriodId': 0,
#          'seasonId': 2020,
#          'statSourceId': 0,
#          'statSplitTypeId': 1,
#          'stats': {}},
#         {'externalId': '401161713',
#          'id': '05401161713',
#          'proTeamId': 7,
#          'scoringPeriodId': 156,
#          'seasonId': 2020,
#          'statSourceId': 0,
#          'statSplitTypeId': 5,
#          'stats': {}},
#         {'externalId': '401161757',
#          'id': '05401161757',
#          'proTeamId': 7,
#          'scoringPeriodId': 162,
#          'seasonId': 2020,
#          'statSourceId': 0,
#          'statSplitTypeId': 5,
#          'stats': {}},
#         {'externalId': '401161700',
#          'id': '05401161700',
#          'proTeamId': 7,
#          'scoringPeriodId': 154,
#          'seasonId': 2020,
#          'statSourceId': 0,
#          'statSplitTypeId': 5,
#          'stats': {}},
#         {'averageStats': {'0': 19.94736842105263,
#           '1': 0.8947368421052632,
#           '2': 1.1973684210526316,
#           '3': 6.605263157894737,
#           '6': 11.302631578947368,
#           '11': 2.8947368421052633,
#           '13': 7.144736842105263,
#           '14': 14.0,
#           '15': 3.6315789473684212,
#           '16': 4.302631578947368,
#           '17': 2.026315789473684,
#           '18': 5.197368421052632,
#           '19': 0.51,
#           '20': 0.846,
#           '21': 0.389,
#           '23': 6.855263157894737,
#           '24': 0.6710526315789473,
#           '25': 3.1710526315789473,
#           '26': 6.6,
#           '27': 0.9,
#           '28': 34.1,
#           '29': 19.9406,
#           '30': 11.3,
#           '31': 1.2,
#           '32': 2.9,
#           '33': 2.0,
#           '34': 0.58,
#           '35': 2.28,
#           '36': 0.41,
#           '40': 34.1,
#           '42': 76.0},
#          'externalId': '2019',
#          'id': '102019',
#          'proTeamId': 0,
#          'scoringPeriodId': 0,
#          'seasonId': 2019,
#          'statSourceId': 1,
#          'statSplitTypeId': 0,
#          'stats': {'0': 1516.0,
#           '1': 68.0,
#           '2': 91.0,
#           '3': 502.0,
#           '6': 859.0,
#           '11': 220.0,
#           '13': 543.0,
#           '14': 1064.0,
#           '15': 276.0,
#           '16': 327.0,
#           '17': 154.0,
#           '18': 395.0,
#           '19': 0.51,
#           '20': 0.846,
#           '21': 0.389,
#           '23': 521.0,
#           '24': 51.0,
#           '25': 241.0,
#           '26': 6.6,
#           '27': 0.9,
#           '28': 34.1,
#           '29': 19.9406,
#           '30': 11.3,
#           '31': 1.2,
#           '32': 2.9,
#           '33': 2.0,
#           '34': 0.58,
#           '35': 2.28,
#           '36': 0.41,
#           '40': 2591.6,
#           '42': 76.0},
#          'variance': {}},
#         {'averageStats': {'0': 20.584415584415584,
#           '1': 0.8051948051948052,
#           '2': 1.2987012987012987,
#           '3': 7.805194805194805,
#           '6': 10.597402597402597,
#           '11': 3.103896103896104,
#           '13': 7.8311688311688314,
#           '14': 15.194805194805195,
#           '15': 3.74025974025974,
#           '16': 4.5064935064935066,
#           '17': 1.1818181818181819,
#           '18': 3.5064935064935066,
#           '19': 0.515,
#           '20': 0.83,
#           '21': 0.338,
#           '26': 7.8,
#           '27': 0.8,
#           '28': 33.6,
#           '29': 20.6,
#           '30': 10.6,
#           '31': 1.3,
#           '32': 3.1,
#           '33': 1.2,
#           '40': 33.599999999999994,
#           '42': 77.0},
#          'externalId': '2020',
#          'id': '102020',
#          'proTeamId': 0,
#          'scoringPeriodId': 0,
#          'seasonId': 2020,
#          'statSourceId': 1,
#          'statSplitTypeId': 0,
#          'stats': {'0': 1585.0,
#           '1': 62.0,
#           '2': 100.0,
#           '3': 601.0,
#           '6': 816.0,
#           '11': 239.0,
#           '13': 603.0,
#           '14': 1170.0,
#           '15': 288.0,
#           '16': 347.0,
#           '17': 91.0,
#           '18': 270.0,
#           '19': 0.515,
#           '20': 0.83,
#           '21': 0.338,
#           '26': 7.8,
#           '27': 0.8,
#           '28': 33.6,
#           '29': 20.6,
#           '30': 10.6,
#           '31': 1.3,
#           '32': 3.1,
#           '33': 1.2,
#           '40': 2587.2,
#           '42': 77.0},
#          'variance': {}},
#         {'averageStats': {'0': 10.666666666666666,
#           '1': 0.0,
#           '2': 0.6666666666666666,
#           '3': 7.666666666666667,
#           '4': 1.3333333333333333,
#           '5': 8.666666666666666,
#           '6': 10.0,
#           '7': 0.0,
#           '8': 0.0,
#           '9': 3.0,
#           '10': 0.0,
#           '11': 3.6666666666666665,
#           '12': 0.0,
#           '13': 5.0,
#           '14': 11.333333333333334,
#           '15': 0.3333333333333333,
#           '16': 1.0,
#           '17': 0.3333333333333333,
#           '18': 3.3333333333333335,
#           '19': 0.44117647,
#           '20': 0.33333333,
#           '21': 0.1,
#           '22': 0.45588235,
#           '23': 6.333333333333333,
#           '24': 0.6666666666666666,
#           '25': 3.0,
#           '26': 7.66666667,
#           '27': 0.0,
#           '28': 32.0,
#           '29': 10.66666667,
#           '30': 10.0,
#           '31': 0.66666667,
#           '32': 3.66666667,
#           '33': 0.33333333,
#           '35': 2.09090909,
#           '36': 0.18181818,
#           '37': 0.3333333333333333,
#           '38': 0.0,
#           '39': 0.0,
#           '40': 32.0,
#           '41': 1.0,
#           '42': 3.0,
#           '43': 0.3333333333333333,
#           '44': 0.08823529},
#          'externalId': '2020',
#          'id': '022020',
#          'proTeamId': 0,
#          'scoringPeriodId': 0,
#          'seasonId': 2020,
#          'statSourceId': 0,
#          'statSplitTypeId': 2,
#          'stats': {'0': 32.0,
#           '1': 0.0,
#           '2': 2.0,
#           '3': 23.0,
#           '4': 4.0,
#           '5': 26.0,
#           '6': 30.0,
#           '7': 0.0,
#           '8': 0.0,
#           '9': 9.0,
#           '10': 0.0,
#           '11': 11.0,
#           '12': 0.0,
#           '13': 15.0,
#           '14': 34.0,
#           '15': 1.0,
#           '16': 3.0,
#           '17': 1.0,
#           '18': 10.0,
#           '19': 0.44117647,
#           '20': 0.33333333,
#           '21': 0.1,
#           '22': 0.45588235,
#           '23': 19.0,
#           '24': 2.0,
#           '25': 9.0,
#           '26': 7.66666667,
#           '27': 0.0,
#           '28': 32.0,
#           '29': 10.66666667,
#           '30': 10.0,
#           '31': 0.66666667,
#           '32': 3.66666667,
#           '33': 0.33333333,
#           '35': 2.09090909,
#           '36': 0.18181818,
#           '37': 1.0,
#           '38': 0.0,
#           '39': 0.0,
#           '40': 96.0,
#           '41': 3.0,
#           '42': 3.0,
#           '43': 1.0,
#           '44': 0.08823529}},
#         {'externalId': '401161691',
#          'id': '05401161691',
#          'proTeamId': 7,
#          'scoringPeriodId': 153,
#          'seasonId': 2020,
#          'statSourceId': 0,
#          'statSplitTypeId': 5,
#          'stats': {}},
#         {'averageStats': {'0': 20.2,
#           '1': 0.6615384615384615,
#           '2': 1.1846153846153846,
#           '3': 6.861538461538461,
#           '4': 2.3846153846153846,
#           '5': 7.815384615384615,
#           '6': 10.2,
#           '7': 0.0,
#           '8': 0.0,
#           '9': 3.076923076923077,
#           '10': 0.046153846153846156,
#           '11': 3.1076923076923078,
#           '12': 0.015384615384615385,
#           '13': 7.876923076923077,
#           '14': 14.907692307692308,
#           '15': 3.353846153846154,
#           '16': 4.123076923076923,
#           '17': 1.0923076923076922,
#           '18': 3.476923076923077,
#           '19': 0.52837977,
#           '20': 0.81343284,
#           '21': 0.31415929,
#           '22': 0.56501548,
#           '23': 7.030769230769231,
#           '24': 0.7692307692307693,
#           '25': 2.3846153846153846,
#           '26': 6.86153846,
#           '27': 0.66153846,
#           '28': 32.35384615,
#           '29': 20.2,
#           '30': 10.2,
#           '31': 1.18461538,
#           '32': 3.10769231,
#           '33': 1.09230769,
#           '35': 2.20792079,
#           '36': 0.38118812,
#           '37': 0.6,
#           '38': 0.18461538461538463,
#           '39': 0.0,
#           '40': 32.353846153846156,
#           '41': 1.0,
#           '42': 65.0,
#           '43': 0.6615384615384615,
#           '44': 0.27657379},
#          'externalId': '2020',
#          'id': '002020',
#          'proTeamId': 0,
#          'scoringPeriodId': 0,
#          'seasonId': 2020,
#          'statSourceId': 0,
#          'statSplitTypeId': 0,
#          'stats': {'0': 1313.0,
#           '1': 43.0,
#           '2': 77.0,
#           '3': 446.0,
#           '4': 155.0,
#           '5': 508.0,
#           '6': 663.0,
#           '7': 0.0,
#           '8': 0.0,
#           '9': 200.0,
#           '10': 3.0,
#           '11': 202.0,
#           '12': 1.0,
#           '13': 512.0,
#           '14': 969.0,
#           '15': 218.0,
#           '16': 268.0,
#           '17': 71.0,
#           '18': 226.0,
#           '19': 0.52837977,
#           '20': 0.81343284,
#           '21': 0.31415929,
#           '22': 0.56501548,
#           '23': 457.0,
#           '24': 50.0,
#           '25': 155.0,
#           '26': 6.86153846,
#           '27': 0.66153846,
#           '28': 32.35384615,
#           '29': 20.2,
#           '30': 10.2,
#           '31': 1.18461538,
#           '32': 3.10769231,
#           '33': 1.09230769,
#           '35': 2.20792079,
#           '36': 0.38118812,
#           '37': 39.0,
#           '38': 12.0,
#           '39': 0.0,
#           '40': 2103.0,
#           '41': 65.0,
#           '42': 65.0,
#           '43': 43.0,
#           '44': 0.27657379}},
#         {'averageStats': {'0': 17.8,
#           '1': 0.6,
#           '2': 1.3,
#           '3': 6.6,
#           '4': 2.1,
#           '5': 7.9,
#           '6': 10.0,
#           '7': 0.0,
#           '8': 0.0,
#           '9': 2.8,
#           '10': 0.0,
#           '11': 3.7,
#           '12': 0.0,
#           '13': 7.2,
#           '14': 12.0,
#           '15': 3.1,
#           '16': 3.7,
#           '17': 0.3,
#           '18': 1.9,
#           '19': 0.6,
#           '20': 0.83783784,
#           '21': 0.15789474,
#           '22': 0.6125,
#           '23': 4.8,
#           '24': 0.6,
#           '25': 1.6,
#           '26': 6.6,
#           '27': 0.6,
#           '28': 31.2,
#           '29': 17.8,
#           '30': 10.0,
#           '31': 1.3,
#           '32': 3.7,
#           '33': 0.3,
#           '35': 1.78378378,
#           '36': 0.35135135,
#           '37': 0.4,
#           '38': 0.1,
#           '39': 0.0,
#           '40': 31.2,
#           '41': 1.0,
#           '42': 10.0,
#           '43': 0.5,
#           '44': 0.30833333},
#          'externalId': '2020',
#          'id': '032020',
#          'proTeamId': 0,
#          'scoringPeriodId': 0,
#          'seasonId': 2020,
#          'statSourceId': 0,
#          'statSplitTypeId': 3,
#          'stats': {'0': 178.0,
#           '1': 6.0,
#           '2': 13.0,
#           '3': 66.0,
#           '4': 21.0,
#           '5': 79.0,
#           '6': 100.0,
#           '7': 0.0,
#           '8': 0.0,
#           '9': 28.0,
#           '10': 0.0,
#           '11': 37.0,
#           '12': 0.0,
#           '13': 72.0,
#           '14': 120.0,
#           '15': 31.0,
#           '16': 37.0,
#           '17': 3.0,
#           '18': 19.0,
#           '19': 0.6,
#           '20': 0.83783784,
#           '21': 0.15789474,
#           '22': 0.6125,
#           '23': 48.0,
#           '24': 6.0,
#           '25': 16.0,
#           '26': 6.6,
#           '27': 0.6,
#           '28': 31.2,
#           '29': 17.8,
#           '30': 10.0,
#           '31': 1.3,
#           '32': 3.7,
#           '33': 0.3,
#           '35': 1.78378378,
#           '36': 0.35135135,
#           '37': 4.0,
#           '38': 1.0,
#           '39': 0.0,
#           '40': 312.0,
#           '41': 10.0,
#           '42': 10.0,
#           '43': 5.0,
#           '44': 0.30833333}},
#         {'externalId': '401161781',
#          'id': '05401161781',
#          'proTeamId': 7,
#          'scoringPeriodId': 165,
#          'seasonId': 2020,
#          'statSourceId': 0,
#          'statSplitTypeId': 5,
#          'stats': {}},
#         {'externalId': '401161731',
#          'id': '05401161731',
#          'proTeamId': 7,
#          'scoringPeriodId': 158,
#          'seasonId': 2020,
#          'statSourceId': 0,
#          'statSplitTypeId': 5,
#          'stats': {}},
#         {'externalId': '401161752',
#          'id': '05401161752',
#          'proTeamId': 7,
#          'scoringPeriodId': 161,
#          'seasonId': 2020,
#          'statSourceId': 0,
#          'statSplitTypeId': 5,
#          'stats': {}},
#         {'averageStats': {'0': 20.05,
#           '1': 0.6875,
#           '2': 1.35,
#           '3': 7.2625,
#           '4': 2.85,
#           '5': 7.9625,
#           '6': 10.8125,
#           '7': 0.0375,
#           '8': 0.0,
#           '9': 2.85,
#           '10': 0.1125,
#           '11': 3.1,
#           '12': 0.025,
#           '13': 7.7,
#           '14': 15.075,
#           '15': 3.6125,
#           '16': 4.4,
#           '17': 1.0375,
#           '18': 3.375,
#           '19': 0.51077944,
#           '20': 0.82102273,
#           '21': 0.30740741,
#           '22': 0.54519071,
#           '23': 7.375,
#           '24': 0.7875,
#           '25': 2.3375,
#           '26': 7.2625,
#           '27': 0.6875,
#           '28': 31.325,
#           '29': 20.05,
#           '30': 10.8125,
#           '31': 1.35,
#           '32': 3.1,
#           '33': 1.0375,
#           '35': 2.34274194,
#           '36': 0.43548387,
#           '37': 0.7,
#           '38': 0.15,
#           '39': 0.0,
#           '40': 31.325,
#           '41': 1.0,
#           '42': 80.0,
#           '43': 0.6625,
#           '44': 0.29187396},
#          'externalId': '2019',
#          'id': '002019',
#          'proTeamId': 0,
#          'scoringPeriodId': 0,
#          'seasonId': 2019,
#          'statSourceId': 0,
#          'statSplitTypeId': 0,
#          'stats': {'0': 1604.0,
#           '1': 55.0,
#           '2': 108.0,
#           '3': 581.0,
#           '4': 228.0,
#           '5': 637.0,
#           '6': 865.0,
#           '7': 3.0,
#           '8': 0.0,
#           '9': 228.0,
#           '10': 9.0,
#           '11': 248.0,
#           '12': 2.0,
#           '13': 616.0,
#           '14': 1206.0,
#           '15': 289.0,
#           '16': 352.0,
#           '17': 83.0,
#           '18': 270.0,
#           '19': 0.51077944,
#           '20': 0.82102273,
#           '21': 0.30740741,
#           '22': 0.54519071,
#           '23': 590.0,
#           '24': 63.0,
#           '25': 187.0,
#           '26': 7.2625,
#           '27': 0.6875,
#           '28': 31.325,
#           '29': 20.05,
#           '30': 10.8125,
#           '31': 1.35,
#           '32': 3.1,
#           '33': 1.0375,
#           '35': 2.34274194,
#           '36': 0.43548387,
#           '37': 56.0,
#           '38': 12.0,
#           '39': 0.0,
#           '40': 2506.0,
#           '41': 80.0,
#           '42': 80.0,
#           '43': 53.0,
#           '44': 0.29187396},
#          'variance': {}}],
#        'universeId': 2},
#       'ratings': {'0': {'positionalRanking': 2,
#         'totalRanking': 5,
#         'totalRating': 12.370938},
#        '1': {'positionalRanking': 0, 'totalRanking': 0, 'totalRating': 0.0},
#        '2': {'positionalRanking': 22,
#         'totalRanking': 157,
#         'totalRating': -0.119226456},
#        '3': {'positionalRanking': 2,
#         'totalRanking': 12,
#         'totalRating': 8.436996}},
#       'rosterLocked': False,
#       'status': 'ONTEAM',
#       'tradeLocked': False},
#      'status': 'NORMAL'},
#     {'acquisitionDate': 1571625036717,
#      'acquisitionType': 'DRAFT',
#      'injuryStatus': 'NORMAL',
#      'lineupSlotId': 2,
#      'pendingTransactionIds': None,
#      'playerId': 6580,
#      'playerPoolEntry': {'id': 6580,
#       'keeperValue': 0,
#       'keeperValueFuture': 2,
#       'lineupLocked': False,
#       'onTeamId': 1,
#       'player': {'active': True,
#        'defaultPositionId': 2,
#        'draftRanksByRankType': {'STANDARD': {'auctionValue': 51,
#          'published': False,
#          'rank': 11,
#          'rankSourceId': 0,
#          'rankType': 'STANDARD',
#          'slotId': 0}},
#        'droppable': False,
#        'eligibleSlots': [1, 2, 5, 6, 7, 8, 10, 11, 12, 13],
#        'firstName': 'Bradley',
#        'fullName': 'Bradley Beal',
#        'id': 6580,
#        'injured': False,
#        'injuryStatus': 'ACTIVE',
#        'lastName': 'Beal',
#        'lastNewsDate': 1583898185000,
#        'lastVideoDate': 1583893784000,
#        'ownership': {'auctionValueAverage': 43.25431034482759,
#         'averageDraftPosition': 15.154642510514396,
#         'percentChange': 0.0,
#         'percentOwned': 99.9999,
#         'percentStarted': 86.77248677248677},
#        'proTeamId': 27,
#        'seasonOutlook': 'Beal ramped up his volume in a big way last season after John Wall tore his Achilles tendon, averaging 28.0 PPG (47.8 FG%, 82.3 FT%), 6.2 APG, 5.3 RPG, 2.8 3PG and 1.9 SPG in 43 games between Dec. 28 and the end of March. Beal will be asked to carry a similar load this season, which gives him top-20 upside in both points and roto leagues.',
#        'stats': [{'externalId': '2020',
#          'id': '012020',
#          'proTeamId': 0,
#          'scoringPeriodId': 0,
#          'seasonId': 2020,
#          'statSourceId': 0,
#          'statSplitTypeId': 1,
#          'stats': {}},
#         {'externalId': '401161735',
#          'id': '05401161735',
#          'proTeamId': 27,
#          'scoringPeriodId': 159,
#          'seasonId': 2020,
#          'statSourceId': 0,
#          'statSplitTypeId': 5,
#          'stats': {}},
#         {'externalId': '401161712',
#          'id': '05401161712',
#          'proTeamId': 27,
#          'scoringPeriodId': 156,
#          'seasonId': 2020,
#          'statSourceId': 0,
#          'statSplitTypeId': 5,
#          'stats': {}},
#         {'averageStats': {'0': 23.307692307692307,
#           '1': 0.3974358974358974,
#           '2': 1.1025641025641026,
#           '3': 4.102564102564102,
#           '6': 4.0,
#           '11': 2.3974358974358974,
#           '13': 8.564102564102564,
#           '14': 17.705128205128204,
#           '15': 3.5256410256410255,
#           '16': 4.397435897435898,
#           '17': 2.6538461538461537,
#           '18': 6.602564102564102,
#           '19': 0.484,
#           '20': 0.8,
#           '21': 0.402,
#           '23': 9.14102564102564,
#           '24': 0.8717948717948718,
#           '25': 3.948717948717949,
#           '26': 4.1,
#           '27': 0.4,
#           '28': 35.9,
#           '29': 23.3068,
#           '30': 4.0,
#           '31': 1.1,
#           '32': 2.4,
#           '33': 3.0,
#           '34': 0.65,
#           '35': 1.71,
#           '36': 0.46,
#           '40': 35.9,
#           '42': 78.0},
#          'externalId': '2019',
#          'id': '102019',
#          'proTeamId': 0,
#          'scoringPeriodId': 0,
#          'seasonId': 2019,
#          'statSourceId': 1,
#          'statSplitTypeId': 0,
#          'stats': {'0': 1818.0,
#           '1': 31.0,
#           '2': 86.0,
#           '3': 320.0,
#           '6': 312.0,
#           '11': 187.0,
#           '13': 668.0,
#           '14': 1381.0,
#           '15': 275.0,
#           '16': 343.0,
#           '17': 207.0,
#           '18': 515.0,
#           '19': 0.484,
#           '20': 0.8,
#           '21': 0.402,
#           '23': 713.0,
#           '24': 68.0,
#           '25': 308.0,
#           '26': 4.1,
#           '27': 0.4,
#           '28': 35.9,
#           '29': 23.3068,
#           '30': 4.0,
#           '31': 1.1,
#           '32': 2.4,
#           '33': 3.0,
#           '34': 0.65,
#           '35': 1.71,
#           '36': 0.46,
#           '40': 2800.2,
#           '42': 78.0},
#          'variance': {}},
#         {'externalId': '401161788',
#          'id': '05401161788',
#          'proTeamId': 27,
#          'scoringPeriodId': 167,
#          'seasonId': 2020,
#          'statSourceId': 0,
#          'statSplitTypeId': 5,
#          'stats': {}},
#         {'averageStats': {'0': 28.308641975308642,
#           '1': 0.6049382716049383,
#           '2': 1.2962962962962963,
#           '3': 5.802469135802469,
#           '6': 4.604938271604938,
#           '11': 2.6049382716049383,
#           '13': 10.123456790123457,
#           '14': 21.506172839506174,
#           '15': 5.074074074074074,
#           '16': 6.296296296296297,
#           '17': 2.9876543209876543,
#           '18': 8.197530864197532,
#           '19': 0.471,
#           '20': 0.806,
#           '21': 0.365,
#           '26': 5.8,
#           '27': 0.6,
#           '28': 36.4,
#           '29': 28.3,
#           '30': 4.6,
#           '31': 1.3,
#           '32': 2.6,
#           '33': 3.0,
#           '40': 36.4,
#           '42': 81.0},
#          'externalId': '2020',
#          'id': '102020',
#          'proTeamId': 0,
#          'scoringPeriodId': 0,
#          'seasonId': 2020,
#          'statSourceId': 1,
#          'statSplitTypeId': 0,
#          'stats': {'0': 2293.0,
#           '1': 49.0,
#           '2': 105.0,
#           '3': 470.0,
#           '6': 373.0,
#           '11': 211.0,
#           '13': 820.0,
#           '14': 1742.0,
#           '15': 411.0,
#           '16': 510.0,
#           '17': 242.0,
#           '18': 664.0,
#           '19': 0.471,
#           '20': 0.806,
#           '21': 0.365,
#           '26': 5.8,
#           '27': 0.6,
#           '28': 36.4,
#           '29': 28.3,
#           '30': 4.6,
#           '31': 1.3,
#           '32': 2.6,
#           '33': 3.0,
#           '40': 2948.4,
#           '42': 81.0},
#          'variance': {}},
#         {'averageStats': {'0': 32.333333333333336,
#           '1': 1.3333333333333333,
#           '2': 1.6666666666666667,
#           '3': 5.666666666666667,
#           '4': 0.0,
#           '5': 3.0,
#           '6': 3.0,
#           '7': 0.0,
#           '8': 0.0,
#           '9': 1.6666666666666667,
#           '10': 0.0,
#           '11': 4.333333333333333,
#           '12': 0.0,
#           '13': 10.666666666666666,
#           '14': 23.333333333333332,
#           '15': 5.666666666666667,
#           '16': 6.333333333333333,
#           '17': 5.333333333333333,
#           '18': 11.333333333333334,
#           '19': 0.45714286,
#           '20': 0.89473684,
#           '21': 0.47058824,
#           '22': 0.57142857,
#           '23': 12.666666666666666,
#           '24': 0.6666666666666666,
#           '25': 6.0,
#           '26': 5.66666667,
#           '27': 1.33333333,
#           '28': 37.66666667,
#           '29': 32.33333333,
#           '30': 3.0,
#           '31': 1.66666667,
#           '32': 4.33333333,
#           '33': 5.33333333,
#           '35': 1.30769231,
#           '36': 0.38461538,
#           '37': 0.0,
#           '38': 0.0,
#           '39': 0.0,
#           '40': 37.666666666666664,
#           '41': 1.0,
#           '42': 3.0,
#           '43': 0.6666666666666666,
#           '44': 0.27142857},
#          'externalId': '2020',
#          'id': '022020',
#          'proTeamId': 0,
#          'scoringPeriodId': 0,
#          'seasonId': 2020,
#          'statSourceId': 0,
#          'statSplitTypeId': 2,
#          'stats': {'0': 97.0,
#           '1': 4.0,
#           '2': 5.0,
#           '3': 17.0,
#           '4': 0.0,
#           '5': 9.0,
#           '6': 9.0,
#           '7': 0.0,
#           '8': 0.0,
#           '9': 5.0,
#           '10': 0.0,
#           '11': 13.0,
#           '12': 0.0,
#           '13': 32.0,
#           '14': 70.0,
#           '15': 17.0,
#           '16': 19.0,
#           '17': 16.0,
#           '18': 34.0,
#           '19': 0.45714286,
#           '20': 0.89473684,
#           '21': 0.47058824,
#           '22': 0.57142857,
#           '23': 38.0,
#           '24': 2.0,
#           '25': 18.0,
#           '26': 5.66666667,
#           '27': 1.33333333,
#           '28': 37.66666667,
#           '29': 32.33333333,
#           '30': 3.0,
#           '31': 1.66666667,
#           '32': 4.33333333,
#           '33': 5.33333333,
#           '35': 1.30769231,
#           '36': 0.38461538,
#           '37': 0.0,
#           '38': 0.0,
#           '39': 0.0,
#           '40': 113.0,
#           '41': 3.0,
#           '42': 3.0,
#           '43': 2.0,
#           '44': 0.27142857}},
#         {'averageStats': {'0': 30.54385964912281,
#           '1': 0.40350877192982454,
#           '2': 1.2456140350877194,
#           '3': 6.087719298245614,
#           '4': 0.9122807017543859,
#           '5': 3.3333333333333335,
#           '6': 4.245614035087719,
#           '7': 0.017543859649122806,
#           '8': 0.017543859649122806,
#           '9': 2.210526315789474,
#           '10': 0.14035087719298245,
#           '11': 3.4035087719298245,
#           '12': 0.0,
#           '13': 10.403508771929825,
#           '14': 22.859649122807017,
#           '15': 6.754385964912281,
#           '16': 8.017543859649123,
#           '17': 2.982456140350877,
#           '18': 8.43859649122807,
#           '19': 0.45510361,
#           '20': 0.84245077,
#           '21': 0.35343035,
#           '22': 0.52033768,
#           '23': 12.456140350877194,
#           '24': 1.263157894736842,
#           '25': 5.456140350877193,
#           '26': 6.0877193,
#           '27': 0.40350877,
#           '28': 36.01754386,
#           '29': 30.54385965,
#           '30': 4.24561404,
#           '31': 1.24561404,
#           '32': 3.40350877,
#           '33': 2.98245614,
#           '35': 1.78865979,
#           '36': 0.36597938,
#           '37': 0.14035087719298245,
#           '38': 0.0,
#           '39': 0.0,
#           '40': 36.01754385964912,
#           '41': 1.0,
#           '42': 57.0,
#           '43': 0.3508771929824561,
#           '44': 0.35072909},
#          'externalId': '2020',
#          'id': '002020',
#          'proTeamId': 0,
#          'scoringPeriodId': 0,
#          'seasonId': 2020,
#          'statSourceId': 0,
#          'statSplitTypeId': 0,
#          'stats': {'0': 1741.0,
#           '1': 23.0,
#           '2': 71.0,
#           '3': 347.0,
#           '4': 52.0,
#           '5': 190.0,
#           '6': 242.0,
#           '7': 1.0,
#           '8': 1.0,
#           '9': 126.0,
#           '10': 8.0,
#           '11': 194.0,
#           '12': 0.0,
#           '13': 593.0,
#           '14': 1303.0,
#           '15': 385.0,
#           '16': 457.0,
#           '17': 170.0,
#           '18': 481.0,
#           '19': 0.45510361,
#           '20': 0.84245077,
#           '21': 0.35343035,
#           '22': 0.52033768,
#           '23': 710.0,
#           '24': 72.0,
#           '25': 311.0,
#           '26': 6.0877193,
#           '27': 0.40350877,
#           '28': 36.01754386,
#           '29': 30.54385965,
#           '30': 4.24561404,
#           '31': 1.24561404,
#           '32': 3.40350877,
#           '33': 2.98245614,
#           '35': 1.78865979,
#           '36': 0.36597938,
#           '37': 8.0,
#           '38': 0.0,
#           '39': 0.0,
#           '40': 2053.0,
#           '41': 57.0,
#           '42': 57.0,
#           '43': 20.0,
#           '44': 0.35072909}},
#         {'externalId': '401161760',
#          'id': '05401161760',
#          'proTeamId': 27,
#          'scoringPeriodId': 163,
#          'seasonId': 2020,
#          'statSourceId': 0,
#          'statSplitTypeId': 5,
#          'stats': {}},
#         {'averageStats': {'0': 36.45454545454545,
#           '1': 0.45454545454545453,
#           '2': 2.090909090909091,
#           '3': 5.636363636363637,
#           '4': 0.6363636363636364,
#           '5': 2.909090909090909,
#           '6': 3.5454545454545454,
#           '7': 0.0,
#           '8': 0.0,
#           '9': 2.4545454545454546,
#           '10': 0.09090909090909091,
#           '11': 4.181818181818182,
#           '12': 0.0,
#           '13': 12.181818181818182,
#           '14': 26.545454545454547,
#           '15': 7.2727272727272725,
#           '16': 8.636363636363637,
#           '17': 4.818181818181818,
#           '18': 10.727272727272727,
#           '19': 0.45890411,
#           '20': 0.84210526,
#           '21': 0.44915254,
#           '22': 0.54965753,
#           '23': 14.363636363636363,
#           '24': 1.3636363636363635,
#           '25': 5.909090909090909,
#           '26': 5.63636364,
#           '27': 0.45454545,
#           '28': 38.09090909,
#           '29': 36.45454545,
#           '30': 3.54545455,
#           '31': 2.09090909,
#           '32': 4.18181818,
#           '33': 4.81818182,
#           '35': 1.34782609,
#           '36': 0.5,
#           '37': 0.09090909090909091,
#           '38': 0.0,
#           '39': 0.0,
#           '40': 38.09090909090909,
#           '41': 1.0,
#           '42': 11.0,
#           '43': 0.36363636363636365,
#           '44': 0.32534247},
#          'externalId': '2020',
#          'id': '032020',
#          'proTeamId': 0,
#          'scoringPeriodId': 0,
#          'seasonId': 2020,
#          'statSourceId': 0,
#          'statSplitTypeId': 3,
#          'stats': {'0': 401.0,
#           '1': 5.0,
#           '2': 23.0,
#           '3': 62.0,
#           '4': 7.0,
#           '5': 32.0,
#           '6': 39.0,
#           '7': 0.0,
#           '8': 0.0,
#           '9': 27.0,
#           '10': 1.0,
#           '11': 46.0,
#           '12': 0.0,
#           '13': 134.0,
#           '14': 292.0,
#           '15': 80.0,
#           '16': 95.0,
#           '17': 53.0,
#           '18': 118.0,
#           '19': 0.45890411,
#           '20': 0.84210526,
#           '21': 0.44915254,
#           '22': 0.54965753,
#           '23': 158.0,
#           '24': 15.0,
#           '25': 65.0,
#           '26': 5.63636364,
#           '27': 0.45454545,
#           '28': 38.09090909,
#           '29': 36.45454545,
#           '30': 3.54545455,
#           '31': 2.09090909,
#           '32': 4.18181818,
#           '33': 4.81818182,
#           '35': 1.34782609,
#           '36': 0.5,
#           '37': 1.0,
#           '38': 0.0,
#           '39': 0.0,
#           '40': 419.0,
#           '41': 11.0,
#           '42': 11.0,
#           '43': 4.0,
#           '44': 0.32534247}},
#         {'externalId': '401161686',
#          'id': '05401161686',
#          'proTeamId': 27,
#          'scoringPeriodId': 152,
#          'seasonId': 2020,
#          'statSourceId': 0,
#          'statSplitTypeId': 5,
#          'stats': {}},
#         {'externalId': '401161697',
#          'id': '05401161697',
#          'proTeamId': 27,
#          'scoringPeriodId': 154,
#          'seasonId': 2020,
#          'statSourceId': 0,
#          'statSplitTypeId': 5,
#          'stats': {}},
#         {'externalId': '401161730',
#          'id': '05401161730',
#          'proTeamId': 27,
#          'scoringPeriodId': 158,
#          'seasonId': 2020,
#          'statSourceId': 0,
#          'statSplitTypeId': 5,
#          'stats': {}},
#         {'externalId': '401161774',
#          'id': '05401161774',
#          'proTeamId': 27,
#          'scoringPeriodId': 165,
#          'seasonId': 2020,
#          'statSourceId': 0,
#          'statSplitTypeId': 5,
#          'stats': {}},
#         {'averageStats': {'0': 25.597560975609756,
#           '1': 0.7073170731707317,
#           '2': 1.475609756097561,
#           '3': 5.463414634146342,
#           '4': 1.0853658536585367,
#           '5': 3.926829268292683,
#           '6': 5.012195121951219,
#           '7': 0.0,
#           '8': 0.0,
#           '9': 2.7560975609756095,
#           '10': 0.12195121951219512,
#           '11': 2.731707317073171,
#           '12': 0.0,
#           '13': 9.317073170731707,
#           '14': 19.621951219512194,
#           '15': 4.414634146341464,
#           '16': 5.463414634146342,
#           '17': 2.548780487804878,
#           '18': 7.2682926829268295,
#           '19': 0.47482909,
#           '20': 0.80803571,
#           '21': 0.35067114,
#           '22': 0.53977626,
#           '23': 10.304878048780488,
#           '24': 1.048780487804878,
#           '25': 4.719512195121951,
#           '26': 5.46341463,
#           '27': 0.70731707,
#           '28': 36.92682927,
#           '29': 25.59756098,
#           '30': 5.01219512,
#           '31': 1.47560976,
#           '32': 2.73170732,
#           '33': 2.54878049,
#           '35': 2.0,
#           '36': 0.54017857,
#           '37': 0.13414634146341464,
#           '38': 0.024390243902439025,
#           '39': 0.0,
#           '40': 36.926829268292686,
#           '41': 1.0,
#           '42': 82.0,
#           '43': 0.3902439024390244,
#           '44': 0.27843381},
#          'externalId': '2019',
#          'id': '002019',
#          'proTeamId': 0,
#          'scoringPeriodId': 0,
#          'seasonId': 2019,
#          'statSourceId': 0,
#          'statSplitTypeId': 0,
#          'stats': {'0': 2099.0,
#           '1': 58.0,
#           '2': 121.0,
#           '3': 448.0,
#           '4': 89.0,
#           '5': 322.0,
#           '6': 411.0,
#           '7': 0.0,
#           '8': 0.0,
#           '9': 226.0,
#           '10': 10.0,
#           '11': 224.0,
#           '12': 0.0,
#           '13': 764.0,
#           '14': 1609.0,
#           '15': 362.0,
#           '16': 448.0,
#           '17': 209.0,
#           '18': 596.0,
#           '19': 0.47482909,
#           '20': 0.80803571,
#           '21': 0.35067114,
#           '22': 0.53977626,
#           '23': 845.0,
#           '24': 86.0,
#           '25': 387.0,
#           '26': 5.46341463,
#           '27': 0.70731707,
#           '28': 36.92682927,
#           '29': 25.59756098,
#           '30': 5.01219512,
#           '31': 1.47560976,
#           '32': 2.73170732,
#           '33': 2.54878049,
#           '35': 2.0,
#           '36': 0.54017857,
#           '37': 11.0,
#           '38': 2.0,
#           '39': 0.0,
#           '40': 3028.0,
#           '41': 82.0,
#           '42': 82.0,
#           '43': 32.0,
#           '44': 0.27843381},
#          'variance': {}}],
#        'universeId': 1},
#       'ratings': {'0': {'positionalRanking': 3,
#         'totalRanking': 11,
#         'totalRating': 9.44449},
#        '1': {'positionalRanking': 0, 'totalRanking': 0, 'totalRating': 0.0},
#        '2': {'positionalRanking': 2,
#         'totalRanking': 4,
#         'totalRating': 10.24049},
#        '3': {'positionalRanking': 1,
#         'totalRanking': 2,
#         'totalRating': 13.021564}},
#       'rosterLocked': False,
#       'status': 'ONTEAM',
#       'tradeLocked': False},
#      'status': 'NORMAL'},
#     {'acquisitionDate': 1571625036718,
#      'acquisitionType': 'DRAFT',
#      'injuryStatus': 'NORMAL',
#      'lineupSlotId': 3,
#      'pendingTransactionIds': None,
#      'playerId': 3102531,
#      'playerPoolEntry': {'id': 3102531,
#       'keeperValue': 0,
#       'keeperValueFuture': 4,
#       'lineupLocked': False,
#       'onTeamId': 1,
#       'player': {'active': True,
#        'defaultPositionId': 4,
#        'draftRanksByRankType': {'STANDARD': {'auctionValue': 18,
#          'published': False,
#          'rank': 41,
#          'rankSourceId': 0,
#          'rankType': 'STANDARD',
#          'slotId': 0}},
#        'droppable': True,
#        'eligibleSlots': [3, 4, 6, 8, 9, 10, 11, 12, 13],
#        'firstName': 'Kristaps',
#        'fullName': 'Kristaps Porzingis',
#        'id': 3102531,
#        'injured': False,
#        'injuryStatus': 'ACTIVE',
#        'lastName': 'Porzingis',
#        'lastNewsDate': 1583948138000,
#        'lastVideoDate': 1583562320000,
#        'ownership': {'auctionValueAverage': 13.905172413793103,
#         'averageDraftPosition': 39.66882486241502,
#         'percentChange': 0.10662358591247312,
#         'percentOwned': 99.9999,
#         'percentStarted': 83.06878306878306},
#        'proTeamId': 6,
#        'seasonOutlook': 'Porzingis sat out the entirety of last season recovering from a spring 2017 torn ACL, and this season will make his debut as a member of the Dallas Mavericks. Porzingis, when healthy, is a legit 20-10 big-man threat with strong shot-blocking and 3-point shooting who would seemingly fit perfectly next to do-everything creator Luka Doncic. But health is such a huge question, so he might slide into the early-to-middle rounds of fantasy drafts despite having top-20 upside.',
#        'stats': [{'externalId': '2020',
#          'id': '012020',
#          'proTeamId': 0,
#          'scoringPeriodId': 0,
#          'seasonId': 2020,
#          'statSourceId': 0,
#          'statSplitTypeId': 1,
#          'stats': {}},
#         {'externalId': '401161702',
#          'id': '05401161702',
#          'proTeamId': 6,
#          'scoringPeriodId': 154,
#          'seasonId': 2020,
#          'statSourceId': 0,
#          'statSplitTypeId': 5,
#          'stats': {}},
#         {'externalId': '401161779',
#          'id': '05401161779',
#          'proTeamId': 6,
#          'scoringPeriodId': 165,
#          'seasonId': 2020,
#          'statSourceId': 0,
#          'statSplitTypeId': 5,
#          'stats': {}},
#         {'externalId': '401161689',
#          'id': '05401161689',
#          'proTeamId': 6,
#          'scoringPeriodId': 152,
#          'seasonId': 2020,
#          'statSourceId': 0,
#          'statSplitTypeId': 5,
#          'stats': {}},
#         {'externalId': '401161722',
#          'id': '05401161722',
#          'proTeamId': 6,
#          'scoringPeriodId': 157,
#          'seasonId': 2020,
#          'statSourceId': 0,
#          'statSplitTypeId': 5,
#          'stats': {}},
#         {'averageStats': {'0': 17.710526315789473,
#           '1': 1.894736842105263,
#           '2': 0.7105263157894737,
#           '3': 1.2105263157894737,
#           '6': 6.2894736842105265,
#           '11': 1.7105263157894737,
#           '13': 6.421052631578948,
#           '14': 14.605263157894736,
#           '15': 3.3421052631578947,
#           '16': 4.2105263157894735,
#           '17': 1.5263157894736843,
#           '18': 4.105263157894737,
#           '19': 0.44,
#           '20': 0.797,
#           '21': 0.372,
#           '23': 8.18421052631579,
#           '24': 0.868421052631579,
#           '25': 2.5789473684210527,
#           '26': 1.2,
#           '27': 1.9,
#           '28': 28.9,
#           '29': 17.7206,
#           '30': 6.3,
#           '31': 0.7,
#           '32': 1.7,
#           '33': 2.0,
#           '34': 0.61,
#           '35': 0.71,
#           '36': 0.42,
#           '40': 28.900000000000002,
#           '42': 38.0},
#          'externalId': '2019',
#          'id': '102019',
#          'proTeamId': 0,
#          'scoringPeriodId': 0,
#          'seasonId': 2019,
#          'statSourceId': 1,
#          'statSplitTypeId': 0,
#          'stats': {'0': 673.0,
#           '1': 72.0,
#           '2': 27.0,
#           '3': 46.0,
#           '6': 239.0,
#           '11': 65.0,
#           '13': 244.0,
#           '14': 555.0,
#           '15': 127.0,
#           '16': 160.0,
#           '17': 58.0,
#           '18': 156.0,
#           '19': 0.44,
#           '20': 0.797,
#           '21': 0.372,
#           '23': 311.0,
#           '24': 33.0,
#           '25': 98.0,
#           '26': 1.2,
#           '27': 1.9,
#           '28': 28.9,
#           '29': 17.7206,
#           '30': 6.3,
#           '31': 0.7,
#           '32': 1.7,
#           '33': 2.0,
#           '34': 0.61,
#           '35': 0.71,
#           '36': 0.42,
#           '40': 1098.2,
#           '42': 38.0},
#          'variance': {}},
#         {'averageStats': {'0': 21.884057971014492,
#           '1': 2.2028985507246377,
#           '2': 0.6956521739130435,
#           '3': 1.3043478260869565,
#           '6': 8.202898550724637,
#           '11': 1.8985507246376812,
#           '13': 8.115942028985508,
#           '14': 17.0,
#           '15': 3.869565217391304,
#           '16': 4.898550724637682,
#           '17': 1.7826086956521738,
#           '18': 4.695652173913044,
#           '19': 0.477,
#           '20': 0.79,
#           '21': 0.379,
#           '26': 1.3,
#           '27': 2.2,
#           '28': 32.5,
#           '29': 21.9,
#           '30': 8.2,
#           '31': 0.7,
#           '32': 1.9,
#           '33': 1.8,
#           '40': 32.5,
#           '42': 69.0},
#          'externalId': '2020',
#          'id': '102020',
#          'proTeamId': 0,
#          'scoringPeriodId': 0,
#          'seasonId': 2020,
#          'statSourceId': 1,
#          'statSplitTypeId': 0,
#          'stats': {'0': 1510.0,
#           '1': 152.0,
#           '2': 48.0,
#           '3': 90.0,
#           '6': 566.0,
#           '11': 131.0,
#           '13': 560.0,
#           '14': 1173.0,
#           '15': 267.0,
#           '16': 338.0,
#           '17': 123.0,
#           '18': 324.0,
#           '19': 0.477,
#           '20': 0.79,
#           '21': 0.379,
#           '26': 1.3,
#           '27': 2.2,
#           '28': 32.5,
#           '29': 21.9,
#           '30': 8.2,
#           '31': 0.7,
#           '32': 1.9,
#           '33': 1.8,
#           '40': 2242.5,
#           '42': 69.0},
#          'variance': {}},
#         {'averageStats': {'0': 14.666666666666666,
#           '1': 2.6666666666666665,
#           '2': 1.0,
#           '3': 3.0,
#           '4': 2.6666666666666665,
#           '5': 7.666666666666667,
#           '6': 10.333333333333334,
#           '7': 0.0,
#           '8': 0.0,
#           '9': 3.6666666666666665,
#           '10': 0.0,
#           '11': 2.3333333333333335,
#           '12': 0.0,
#           '13': 5.333333333333333,
#           '14': 17.0,
#           '15': 2.3333333333333335,
#           '16': 3.0,
#           '17': 1.6666666666666667,
#           '18': 7.333333333333333,
#           '19': 0.31372549,
#           '20': 0.77777778,
#           '21': 0.22727273,
#           '22': 0.3627451,
#           '23': 11.666666666666666,
#           '24': 0.6666666666666666,
#           '25': 5.666666666666667,
#           '26': 3.0,
#           '27': 2.66666667,
#           '28': 35.0,
#           '29': 14.66666667,
#           '30': 10.33333333,
#           '31': 1.0,
#           '32': 2.33333333,
#           '33': 1.66666667,
#           '35': 1.28571429,
#           '36': 0.42857143,
#           '37': 0.3333333333333333,
#           '38': 0.0,
#           '39': 0.0,
#           '40': 35.0,
#           '41': 1.0,
#           '42': 3.0,
#           '43': 0.3333333333333333,
#           '44': 0.17647059},
#          'externalId': '2020',
#          'id': '022020',
#          'proTeamId': 0,
#          'scoringPeriodId': 0,
#          'seasonId': 2020,
#          'statSourceId': 0,
#          'statSplitTypeId': 2,
#          'stats': {'0': 44.0,
#           '1': 8.0,
#           '2': 3.0,
#           '3': 9.0,
#           '4': 8.0,
#           '5': 23.0,
#           '6': 31.0,
#           '7': 0.0,
#           '8': 0.0,
#           '9': 11.0,
#           '10': 0.0,
#           '11': 7.0,
#           '12': 0.0,
#           '13': 16.0,
#           '14': 51.0,
#           '15': 7.0,
#           '16': 9.0,
#           '17': 5.0,
#           '18': 22.0,
#           '19': 0.31372549,
#           '20': 0.77777778,
#           '21': 0.22727273,
#           '22': 0.3627451,
#           '23': 35.0,
#           '24': 2.0,
#           '25': 17.0,
#           '26': 3.0,
#           '27': 2.66666667,
#           '28': 35.0,
#           '29': 14.66666667,
#           '30': 10.33333333,
#           '31': 1.0,
#           '32': 2.33333333,
#           '33': 1.66666667,
#           '35': 1.28571429,
#           '36': 0.42857143,
#           '37': 1.0,
#           '38': 0.0,
#           '39': 0.0,
#           '40': 105.0,
#           '41': 3.0,
#           '42': 3.0,
#           '43': 1.0,
#           '44': 0.17647059}},
#         {'averageStats': {'0': 19.235294117647058,
#           '1': 2.0784313725490198,
#           '2': 0.7058823529411765,
#           '3': 1.7450980392156863,
#           '4': 1.7450980392156863,
#           '5': 7.7254901960784315,
#           '6': 9.470588235294118,
#           '7': 0.0,
#           '8': 0.0,
#           '9': 3.0784313725490198,
#           '10': 0.09803921568627451,
#           '11': 1.6470588235294117,
#           '12': 0.0392156862745098,
#           '13': 6.647058823529412,
#           '14': 15.843137254901961,
#           '15': 3.4705882352941178,
#           '16': 4.470588235294118,
#           '17': 2.4705882352941178,
#           '18': 7.078431372549019,
#           '19': 0.41955446,
#           '20': 0.77631579,
#           '21': 0.34903047,
#           '22': 0.49752475,
#           '23': 9.196078431372548,
#           '24': 1.0,
#           '25': 4.607843137254902,
#           '26': 1.74509804,
#           '27': 2.07843137,
#           '28': 31.33333333,
#           '29': 19.23529412,
#           '30': 9.47058824,
#           '31': 0.70588235,
#           '32': 1.64705882,
#           '33': 2.47058824,
#           '35': 1.05952381,
#           '36': 0.42857143,
#           '37': 0.45098039215686275,
#           '38': 0.0,
#           '39': 0.0,
#           '40': 31.333333333333332,
#           '41': 1.0,
#           '42': 51.0,
#           '43': 0.5882352941176471,
#           '44': 0.28217822},
#          'externalId': '2020',
#          'id': '002020',
#          'proTeamId': 0,
#          'scoringPeriodId': 0,
#          'seasonId': 2020,
#          'statSourceId': 0,
#          'statSplitTypeId': 0,
#          'stats': {'0': 981.0,
#           '1': 106.0,
#           '2': 36.0,
#           '3': 89.0,
#           '4': 89.0,
#           '5': 394.0,
#           '6': 483.0,
#           '7': 0.0,
#           '8': 0.0,
#           '9': 157.0,
#           '10': 5.0,
#           '11': 84.0,
#           '12': 2.0,
#           '13': 339.0,
#           '14': 808.0,
#           '15': 177.0,
#           '16': 228.0,
#           '17': 126.0,
#           '18': 361.0,
#           '19': 0.41955446,
#           '20': 0.77631579,
#           '21': 0.34903047,
#           '22': 0.49752475,
#           '23': 469.0,
#           '24': 51.0,
#           '25': 235.0,
#           '26': 1.74509804,
#           '27': 2.07843137,
#           '28': 31.33333333,
#           '29': 19.23529412,
#           '30': 9.47058824,
#           '31': 0.70588235,
#           '32': 1.64705882,
#           '33': 2.47058824,
#           '35': 1.05952381,
#           '36': 0.42857143,
#           '37': 23.0,
#           '38': 0.0,
#           '39': 0.0,
#           '40': 1598.0,
#           '41': 51.0,
#           '42': 51.0,
#           '43': 30.0,
#           '44': 0.28217822}},
#         {'averageStats': {'0': 23.0,
#           '1': 3.0,
#           '2': 0.6666666666666666,
#           '3': 3.0,
#           '4': 2.3333333333333335,
#           '5': 8.777777777777779,
#           '6': 11.11111111111111,
#           '7': 0.0,
#           '8': 0.0,
#           '9': 2.7777777777777777,
#           '10': 0.1111111111111111,
#           '11': 1.5555555555555556,
#           '12': 0.0,
# ...
#          'statSplitTypeId': 1,
#          'stats': {}},
#         {'externalId': '401161723',
#          'id': '05401161723',
#          'proTeamId': 1,
#          'scoringPeriodId': 157,
#          'seasonId': 2020,
#          'statSourceId': 0,
#          'statSplitTypeId': 5,
#          'stats': {}},
#         {'externalId': '401161755',
#          'id': '05401161755',
#          'proTeamId': 1,
#          'scoringPeriodId': 162,
#          'seasonId': 2020,
#          'statSourceId': 0,
#          'statSplitTypeId': 5,
#          'stats': {}},
#         {'averageStats': {'0': 7.743243243243243,
#           '1': 0.0945945945945946,
#           '2': 0.7027027027027027,
#           '3': 1.7027027027027026,
#           '6': 2.7027027027027026,
#           '11': 1.2972972972972974,
#           '13': 2.5135135135135136,
#           '14': 5.702702702702703,
#           '15': 1.2432432432432432,
#           '16': 1.5,
#           '17': 1.472972972972973,
#           '18': 3.9054054054054053,
#           '19': 0.441,
#           '20': 0.831,
#           '21': 0.378,
#           '23': 3.189189189189189,
#           '24': 0.25675675675675674,
#           '25': 2.4324324324324325,
#           '26': 1.7,
#           '27': 0.1,
#           '28': 17.6,
#           '29': 7.7481,
#           '30': 2.7,
#           '31': 0.7,
#           '32': 1.3,
#           '33': 1.0,
#           '34': 0.44,
#           '35': 1.31,
#           '36': 0.54,
#           '40': 17.6,
#           '42': 74.0},
#          'externalId': '2019',
#          'id': '102019',
#          'proTeamId': 0,
#          'scoringPeriodId': 0,
#          'seasonId': 2019,
#          'statSourceId': 1,
#          'statSplitTypeId': 0,
#          'stats': {'0': 573.0,
#           '1': 7.0,
#           '2': 52.0,
#           '3': 126.0,
#           '6': 200.0,
#           '11': 96.0,
#           '13': 186.0,
#           '14': 422.0,
#           '15': 92.0,
#           '16': 111.0,
#           '17': 109.0,
#           '18': 289.0,
#           '19': 0.441,
#           '20': 0.831,
#           '21': 0.378,
#           '23': 236.0,
#           '24': 19.0,
#           '25': 180.0,
#           '26': 1.7,
#           '27': 0.1,
#           '28': 17.6,
#           '29': 7.7481,
#           '30': 2.7,
#           '31': 0.7,
#           '32': 1.3,
#           '33': 1.0,
#           '34': 0.44,
#           '35': 1.31,
#           '36': 0.54,
#           '40': 1302.4,
#           '42': 74.0},
#          'variance': {}},
#         {'externalId': '401161717',
#          'id': '05401161717',
#          'proTeamId': 1,
#          'scoringPeriodId': 156,
#          'seasonId': 2020,
#          'statSourceId': 0,
#          'statSplitTypeId': 5,
#          'stats': {}},
#         {'externalId': '401161739',
#          'id': '05401161739',
#          'proTeamId': 1,
#          'scoringPeriodId': 159,
#          'seasonId': 2020,
#          'statSourceId': 0,
#          'statSplitTypeId': 5,
#          'stats': {}},
#         {'averageStats': {'0': 12.064102564102564,
#           '1': 0.3974358974358974,
#           '2': 1.1025641025641026,
#           '3': 3.5,
#           '6': 4.0,
#           '11': 1.794871794871795,
#           '13': 4.564102564102564,
#           '14': 10.705128205128204,
#           '15': 0.6794871794871795,
#           '16': 0.8974358974358975,
#           '17': 2.2564102564102564,
#           '18': 5.705128205128205,
#           '19': 0.426,
#           '20': 0.762,
#           '21': 0.395,
#           '26': 3.5,
#           '27': 0.4,
#           '28': 33.2,
#           '29': 12.1,
#           '30': 4.0,
#           '31': 1.1,
#           '32': 1.8,
#           '33': 2.3,
#           '40': 33.199999999999996,
#           '42': 78.0},
#          'externalId': '2020',
#          'id': '102020',
#          'proTeamId': 0,
#          'scoringPeriodId': 0,
#          'seasonId': 2020,
#          'statSourceId': 1,
#          'statSplitTypeId': 0,
#          'stats': {'0': 941.0,
#           '1': 31.0,
#           '2': 86.0,
#           '3': 273.0,
#           '6': 312.0,
#           '11': 140.0,
#           '13': 356.0,
#           '14': 835.0,
#           '15': 53.0,
#           '16': 70.0,
#           '17': 176.0,
#           '18': 445.0,
#           '19': 0.426,
#           '20': 0.762,
#           '21': 0.395,
#           '26': 3.5,
#           '27': 0.4,
#           '28': 33.2,
#           '29': 12.1,
#           '30': 4.0,
#           '31': 1.1,
#           '32': 1.8,
#           '33': 2.3,
#           '40': 2589.6,
#           '42': 78.0},
#          'variance': {}},
#         {'averageStats': {'0': 10.75,
#           '1': 0.5,
#           '2': 1.0,
#           '3': 7.5,
#           '4': 0.25,
#           '5': 3.0,
#           '6': 3.25,
#           '7': 0.0,
#           '8': 0.0,
#           '9': 3.5,
#           '10': 0.0,
#           '11': 1.5,
#           '12': 0.0,
#           '13': 4.5,
#           '14': 11.5,
#           '15': 0.0,
#           '16': 0.0,
#           '17': 1.75,
#           '18': 6.25,
#           '19': 0.39130435,
#           '20': 0.0,
#           '21': 0.28,
#           '22': 0.4673913,
#           '23': 7.0,
#           '24': 0.0,
#           '25': 4.5,
#           '26': 7.5,
#           '27': 0.5,
#           '28': 37.75,
#           '29': 10.75,
#           '30': 3.25,
#           '31': 1.0,
#           '32': 1.5,
#           '33': 1.75,
#           '35': 5.0,
#           '36': 0.66666667,
#           '37': 0.25,
#           '38': 0.0,
#           '39': 0.0,
#           '40': 37.75,
#           '41': 1.0,
#           '42': 4.0,
#           '43': 0.25,
#           '44': 0.0},
#          'externalId': '2020',
#          'id': '022020',
#          'proTeamId': 0,
#          'scoringPeriodId': 0,
#          'seasonId': 2020,
#          'statSourceId': 0,
#          'statSplitTypeId': 2,
#          'stats': {'0': 43.0,
#           '1': 2.0,
#           '2': 4.0,
#           '3': 30.0,
#           '4': 1.0,
#           '5': 12.0,
#           '6': 13.0,
#           '7': 0.0,
#           '8': 0.0,
#           '9': 14.0,
#           '10': 0.0,
#           '11': 6.0,
#           '12': 0.0,
#           '13': 18.0,
#           '14': 46.0,
#           '15': 0.0,
#           '16': 0.0,
#           '17': 7.0,
#           '18': 25.0,
#           '19': 0.39130435,
#           '20': 0.0,
#           '21': 0.28,
#           '22': 0.4673913,
#           '23': 28.0,
#           '24': 0.0,
#           '25': 18.0,
#           '26': 7.5,
#           '27': 0.5,
#           '28': 37.75,
#           '29': 10.75,
#           '30': 3.25,
#           '31': 1.0,
#           '32': 1.5,
#           '33': 1.75,
#           '35': 5.0,
#           '36': 0.66666667,
#           '37': 1.0,
#           '38': 0.0,
#           '39': 0.0,
#           '40': 151.0,
#           '41': 4.0,
#           '42': 4.0,
#           '43': 1.0,
#           '44': 0.0}},
#         {'averageStats': {'0': 12.214285714285714,
#           '1': 0.48214285714285715,
#           '2': 0.9107142857142857,
#           '3': 3.8214285714285716,
#           '4': 0.625,
#           '5': 3.4464285714285716,
#           '6': 4.071428571428571,
#           '7': 0.0,
#           '8': 0.0,
#           '9': 2.482142857142857,
#           '10': 0.03571428571428571,
#           '11': 1.5535714285714286,
#           '12': 0.017857142857142856,
#           '13': 4.5,
#           '14': 10.892857142857142,
#           '15': 0.9464285714285714,
#           '16': 1.1428571428571428,
#           '17': 2.267857142857143,
#           '18': 5.964285714285714,
#           '19': 0.41311475,
#           '20': 0.828125,
#           '21': 0.38023952,
#           '22': 0.51721311,
#           '23': 6.392857142857143,
#           '24': 0.19642857142857142,
#           '25': 3.6964285714285716,
#           '26': 3.82142857,
#           '27': 0.48214286,
#           '28': 31.5,
#           '29': 12.21428571,
#           '30': 4.07142857,
#           '31': 0.91071429,
#           '32': 1.55357143,
#           '33': 2.26785714,
#           '35': 2.45977011,
#           '36': 0.5862069,
#           '37': 0.03571428571428571,
#           '38': 0.0,
#           '39': 0.0,
#           '40': 31.5,
#           '41': 0.8571428571428571,
#           '42': 56.0,
#           '43': 0.3392857142857143,
#           '44': 0.10491803},
#          'externalId': '2020',
#          'id': '002020',
#          'proTeamId': 0,
#          'scoringPeriodId': 0,
#          'seasonId': 2020,
#          'statSourceId': 0,
#          'statSplitTypeId': 0,
#          'stats': {'0': 684.0,
#           '1': 27.0,
#           '2': 51.0,
#           '3': 214.0,
#           '4': 35.0,
#           '5': 193.0,
#           '6': 228.0,
#           '7': 0.0,
#           '8': 0.0,
#           '9': 139.0,
#           '10': 2.0,
#           '11': 87.0,
#           '12': 1.0,
#           '13': 252.0,
#           '14': 610.0,
#           '15': 53.0,
#           '16': 64.0,
#           '17': 127.0,
#           '18': 334.0,
#           '19': 0.41311475,
#           '20': 0.828125,
#           '21': 0.38023952,
#           '22': 0.51721311,
#           '23': 358.0,
#           '24': 11.0,
#           '25': 207.0,
#           '26': 3.82142857,
#           '27': 0.48214286,
#           '28': 31.5,
#           '29': 12.21428571,
#           '30': 4.07142857,
#           '31': 0.91071429,
#           '32': 1.55357143,
#           '33': 2.26785714,
#           '35': 2.45977011,
#           '36': 0.5862069,
#           '37': 2.0,
#           '38': 0.0,
#           '39': 0.0,
#           '40': 1764.0,
#           '41': 48.0,
#           '42': 56.0,
#           '43': 19.0,
#           '44': 0.10491803}},
#         {'externalId': '401161684',
#          'id': '05401161684',
#          'proTeamId': 1,
#          'scoringPeriodId': 152,
#          'seasonId': 2020,
#          'statSourceId': 0,
#          'statSplitTypeId': 5,
#          'stats': {}},
#         {'averageStats': {'0': 12.0,
#           '1': 0.5454545454545454,
#           '2': 1.2727272727272727,
#           '3': 5.636363636363637,
#           '4': 0.7272727272727273,
#           '5': 3.272727272727273,
#           '6': 4.0,
#           '7': 0.0,
#           '8': 0.0,
#           '9': 2.727272727272727,
#           '10': 0.0,
#           '11': 1.1818181818181819,
#           '12': 0.0,
#           '13': 4.636363636363637,
#           '14': 11.727272727272727,
#           '15': 0.5454545454545454,
#           '16': 0.6363636363636364,
#           '17': 2.1818181818181817,
#           '18': 6.454545454545454,
#           '19': 0.39534884,
#           '20': 0.85714286,
#           '21': 0.33802817,
#           '22': 0.48837209,
#           '23': 7.090909090909091,
#           '24': 0.09090909090909091,
#           '25': 4.2727272727272725,
#           '26': 5.63636364,
#           '27': 0.54545455,
#           '28': 36.09090909,
#           '29': 12.0,
#           '30': 4.0,
#           '31': 1.27272727,
#           '32': 1.18181818,
#           '33': 2.18181818,
#           '35': 4.76923077,
#           '36': 1.07692308,
#           '37': 0.09090909090909091,
#           '38': 0.0,
#           '39': 0.0,
#           '40': 36.09090909090909,
#           '41': 1.0,
#           '42': 11.0,
#           '43': 0.45454545454545453,
#           '44': 0.05426357},
#          'externalId': '2020',
#          'id': '032020',
#          'proTeamId': 0,
#          'scoringPeriodId': 0,
#          'seasonId': 2020,
#          'statSourceId': 0,
#          'statSplitTypeId': 3,
#          'stats': {'0': 132.0,
#           '1': 6.0,
#           '2': 14.0,
#           '3': 62.0,
#           '4': 8.0,
#           '5': 36.0,
#           '6': 44.0,
#           '7': 0.0,
#           '8': 0.0,
#           '9': 30.0,
#           '10': 0.0,
#           '11': 13.0,
#           '12': 0.0,
#           '13': 51.0,
#           '14': 129.0,
#           '15': 6.0,
#           '16': 7.0,
#           '17': 24.0,
#           '18': 71.0,
#           '19': 0.39534884,
#           '20': 0.85714286,
#           '21': 0.33802817,
#           '22': 0.48837209,
#           '23': 78.0,
#           '24': 1.0,
#           '25': 47.0,
#           '26': 5.63636364,
#           '27': 0.54545455,
#           '28': 36.09090909,
#           '29': 12.0,
#           '30': 4.0,
#           '31': 1.27272727,
#           '32': 1.18181818,
#           '33': 2.18181818,
#           '35': 4.76923077,
#           '36': 1.07692308,
#           '37': 1.0,
#           '38': 0.0,
#           '39': 0.0,
#           '40': 397.0,
#           '41': 11.0,
#           '42': 11.0,
#           '43': 5.0,
#           '44': 0.05426357}},
#         {'externalId': '401161775',
#          'id': '05401161775',
#          'proTeamId': 1,
#          'scoringPeriodId': 165,
#          'seasonId': 2020,
#          'statSourceId': 0,
#          'statSplitTypeId': 5,
#          'stats': {}},
#         {'externalId': '401161785',
#          'id': '05401161785',
#          'proTeamId': 1,
#          'scoringPeriodId': 167,
#          'seasonId': 2020,
#          'statSourceId': 0,
#          'statSplitTypeId': 5,
#          'stats': {}},
#         {'averageStats': {'0': 9.693333333333333,
#           '1': 0.3333333333333333,
#           '2': 0.8666666666666667,
#           '3': 2.8533333333333335,
#           '4': 0.8,
#           '5': 2.466666666666667,
#           '6': 3.2666666666666666,
#           '7': 0.0,
#           '8': 0.0,
#           '9': 2.066666666666667,
#           '10': 0.0,
#           '11': 1.4533333333333334,
#           '12': 0.0,
#           '13': 3.6666666666666665,
#           '14': 8.76,
#           '15': 0.5466666666666666,
#           '16': 0.7466666666666667,
#           '17': 1.8133333333333332,
#           '18': 4.706666666666667,
#           '19': 0.41856925,
#           '20': 0.73214286,
#           '21': 0.38526912,
#           '22': 0.52207002,
#           '23': 5.093333333333334,
#           '24': 0.2,
#           '25': 2.8933333333333335,
#           '26': 2.85333333,
#           '27': 0.33333333,
#           '28': 27.22666667,
#           '29': 9.69333333,
#           '30': 3.26666667,
#           '31': 0.86666667,
#           '32': 1.45333333,
#           '33': 1.81333333,
#           '35': 1.96330275,
#           '36': 0.59633028,
#           '37': 0.013333333333333334,
#           '38': 0.0,
#           '39': 0.0,
#           '40': 27.226666666666667,
#           '41': 0.7866666666666666,
#           '42': 75.0,
#           '43': 0.36,
#           '44': 0.08523592},
#          'externalId': '2019',
#          'id': '002019',
#          'proTeamId': 0,
#          'scoringPeriodId': 0,
#          'seasonId': 2019,
#          'statSourceId': 0,
#          'statSplitTypeId': 0,
#          'stats': {'0': 727.0,
#           '1': 25.0,
#           '2': 65.0,
#           '3': 214.0,
#           '4': 60.0,
#           '5': 185.0,
#           '6': 245.0,
#           '7': 0.0,
#           '8': 0.0,
#           '9': 155.0,
#           '10': 0.0,
#           '11': 109.0,
#           '12': 0.0,
#           '13': 275.0,
#           '14': 657.0,
#           '15': 41.0,
#           '16': 56.0,
#           '17': 136.0,
#           '18': 353.0,
#           '19': 0.41856925,
#           '20': 0.73214286,
#           '21': 0.38526912,
#           '22': 0.52207002,
#           '23': 382.0,
#           '24': 15.0,
#           '25': 217.0,
#           '26': 2.85333333,
#           '27': 0.33333333,
#           '28': 27.22666667,
#           '29': 9.69333333,
#           '30': 3.26666667,
#           '31': 0.86666667,
#           '32': 1.45333333,
#           '33': 1.81333333,
#           '35': 1.96330275,
#           '36': 0.59633028,
#           '37': 1.0,
#           '38': 0.0,
#           '39': 0.0,
#           '40': 2042.0,
#           '41': 59.0,
#           '42': 75.0,
#           '43': 27.0,
#           '44': 0.08523592},
#          'variance': {}}],
#        'universeId': 1},
#       'ratings': {'0': {'positionalRanking': 29,
#         'totalRanking': 121,
#         'totalRating': 3.2952545},
#        '1': {'positionalRanking': 0, 'totalRanking': 0, 'totalRating': 0.0},
#        '2': {'positionalRanking': 9,
#         'totalRanking': 43,
#         'totalRating': 5.406581},
#        '3': {'positionalRanking': 9,
#         'totalRanking': 49,
#         'totalRating': 5.4250226}},
#       'rosterLocked': False,
#       'status': 'ONTEAM',
#       'tradeLocked': False},
#      'status': 'NORMAL'}]},
#   'tradeBlock': {},
#   'transactionCounter': {'acquisitionBudgetSpent': 0,
#    'acquisitions': 6,
#    'drops': 6,
#    'matchupAcquisitionTotals': {'1': 1,
#     '4': 1,
#     '5': 1,
#     '9': 1,
#     '17': 1,
#     '20': 1},
#    'misc': 0,
#    'moveToActive': 194,
#    'moveToIR': 0,
#    'paid': 0.0,
#    'teamCharges': 0.0,
#    'trades': 1},
#   'valuesByStat': {'0': 13159.0,
#    '1': 346.0,
#    '2': 704.0,
#    '3': 2534.0,
#    '6': 4382.0,
#    '11': 1655.0,
#    '13': 4693.0,
#    '14': 10049.0,
#    '15': 2584.0,
#    '16': 3310.0,
#    '17': 1189.0,
#    '19': 0.46701164,
#    '20': 0.78066465},
#   'waiverRank': 4}]

# %%
def parse_api_to_rosters():
    data = call_espn_api(65116266)
    rosters = [[Player("") for i in range(13)] for j in range(10)]
    for i in range(10):
        for j in range(len(data["teams"][i]['roster']['entries'])):
            rosters[i][j] = Player(data["teams"][i]['roster']['entries'][j]['playerPoolEntry']['player']['fullName'])
            x = data["teams"][i]['roster']['entries'][j]['playerPoolEntry']['player']['stats']
            statIndex = 0
            for k in range(len(x)):
                if x[k]['seasonId'] == 2020 and x[k]['statSplitTypeId'] == 0 and x[k]['externalId'] == '2020' and x[k]['statSourceId'] == 0:
                    statIndex = k
                    if not x[k]['stats']:
                        for l in range(len(x)):
                            if x[l]['seasonId'] == 2019 and x[l]['statSplitTypeId'] == 0 and x[l]['externalId'] == '2019' and x[l]['statSourceId'] == 0:
                                statIndex = l
            seasonStats = x[statIndex]['averageStats']
            rosters[i][j].pts = seasonStats['0']
            rosters[i][j].fgm = seasonStats['13']
            rosters[i][j].fga = seasonStats['14']
            rosters[i][j].fgp = seasonStats['13'] / seasonStats['14']
            rosters[i][j].ftm = seasonStats['15']
            rosters[i][j].fta = seasonStats['16']
            rosters[i][j].ftp = seasonStats['15'] / seasonStats['16']
            rosters[i][j].rbs = seasonStats['6']
            rosters[i][j].ast = seasonStats['3']
            rosters[i][j].stl = seasonStats['2']
            rosters[i][j].blk = seasonStats['1']
            rosters[i][j].tov = seasonStats['11']
            rosters[i][j].m3s = seasonStats['17']
    return rosters
rosters = parse_api_to_rosters()
for roster in rosters:
    for player in roster:
        print(player)
    print()
# Out:
# [2020-03-21 16:15:54,920] INFO in <ipython-input-15-4304b857eff1>: 65116266 - Calling ESPN API
# Nikola Jokic pts/reb/ast: 20.20/10.20/6.86 stl/blk/tov: 1.18/0.66/3.11/ fg%/ft%/3pm: 0.53/0.81/1.09
# Bradley Beal pts/reb/ast: 30.54/4.25/6.09 stl/blk/tov: 1.25/0.40/3.40/ fg%/ft%/3pm: 0.46/0.84/2.98
# Kristaps Porzingis pts/reb/ast: 19.24/9.47/1.75 stl/blk/tov: 0.71/2.08/1.65/ fg%/ft%/3pm: 0.42/0.78/2.47
# Hassan Whiteside pts/reb/ast: 16.28/14.25/1.21 stl/blk/tov: 0.39/3.07/1.92/ fg%/ft%/3pm: 0.62/0.68/0.07
# Lou Williams pts/reb/ast: 18.65/3.10/5.73 stl/blk/tov: 0.67/0.17/2.87/ fg%/ft%/3pm: 0.42/0.86/1.78
# Duncan Robinson pts/reb/ast: 13.28/3.26/1.40 stl/blk/tov: 0.54/0.23/0.92/ fg%/ft%/3pm: 0.47/0.91/3.74
# Stephen Curry pts/reb/ast: 20.80/5.20/6.60 stl/blk/tov: 1.00/0.40/3.20/ fg%/ft%/3pm: 0.40/1.00/2.40
# Seth Curry pts/reb/ast: 12.58/2.36/2.02 stl/blk/tov: 0.61/0.14/1.02/ fg%/ft%/3pm: 0.50/0.84/2.31
# Coby White pts/reb/ast: 13.22/3.54/2.69 stl/blk/tov: 0.75/0.09/1.68/ fg%/ft%/3pm: 0.39/0.79/2.05
# Al Horford pts/reb/ast: 12.03/6.87/4.07 stl/blk/tov: 0.87/0.92/1.08/ fg%/ft%/3pm: 0.44/0.75/1.48
# Ricky Rubio pts/reb/ast: 13.05/4.65/8.89 stl/blk/tov: 1.54/0.16/2.72/ fg%/ft%/3pm: 0.41/0.85/1.16
# Dennis Schroder pts/reb/ast: 19.03/3.70/4.06 stl/blk/tov: 0.68/0.22/2.52/ fg%/ft%/3pm: 0.47/0.84/1.94
# Malcolm Brogdon pts/reb/ast: 16.33/4.71/7.15 stl/blk/tov: 0.69/0.17/2.40/ fg%/ft%/3pm: 0.44/0.90/1.27
#
# Kawhi Leonard pts/reb/ast: 26.86/7.31/4.98 stl/blk/tov: 1.80/0.61/2.75/ fg%/ft%/3pm: 0.47/0.89/2.10
# Buddy Hield pts/reb/ast: 19.81/4.78/3.08 stl/blk/tov: 0.94/0.27/2.34/ fg%/ft%/3pm: 0.43/0.85/3.81
# Jamal Murray pts/reb/ast: 18.78/3.95/4.84 stl/blk/tov: 1.16/0.29/2.25/ fg%/ft%/3pm: 0.46/0.89/1.91
# Danilo Gallinari pts/reb/ast: 19.22/5.49/2.05 stl/blk/tov: 0.73/0.07/1.27/ fg%/ft%/3pm: 0.44/0.89/3.00
# Domantas Sabonis pts/reb/ast: 18.50/12.44/5.00 stl/blk/tov: 0.76/0.48/2.74/ fg%/ft%/3pm: 0.54/0.72/0.27
# Ja Morant pts/reb/ast: 17.64/3.53/6.93 stl/blk/tov: 0.92/0.25/3.24/ fg%/ft%/3pm: 0.49/0.77/0.86
# Joe Harris pts/reb/ast: 13.94/4.32/2.06 stl/blk/tov: 0.60/0.25/1.48/ fg%/ft%/3pm: 0.47/0.75/2.41
# Khris Middleton pts/reb/ast: 21.07/6.20/4.09 stl/blk/tov: 0.93/0.13/2.05/ fg%/ft%/3pm: 0.50/0.91/2.42
# Nemanja Bjelica pts/reb/ast: 11.86/6.44/2.80 stl/blk/tov: 0.84/0.52/1.44/ fg%/ft%/3pm: 0.48/0.82/1.95
# Kendrick Nunn pts/reb/ast: 15.65/2.71/3.39 stl/blk/tov: 0.82/0.18/1.63/ fg%/ft%/3pm: 0.45/0.84/2.11
# Shake Milton pts/reb/ast: 9.47/2.12/2.22 stl/blk/tov: 0.59/0.19/1.19/ fg%/ft%/3pm: 0.50/0.76/1.50
# Thomas Bryant pts/reb/ast: 12.11/6.84/1.87 stl/blk/tov: 0.37/0.87/1.26/ fg%/ft%/3pm: 0.60/0.74/0.58
# Larry Nance Jr. pts/reb/ast: 10.07/7.30/2.20 stl/blk/tov: 1.00/0.39/1.07/ fg%/ft%/3pm: 0.53/0.68/1.00
#
# Damian Lillard pts/reb/ast: 28.91/4.31/7.81 stl/blk/tov: 1.02/0.36/2.90/ fg%/ft%/3pm: 0.46/0.89/3.90
# Paul George pts/reb/ast: 20.95/5.74/3.86 stl/blk/tov: 1.33/0.48/2.69/ fg%/ft%/3pm: 0.43/0.88/3.17
# Devin Booker pts/reb/ast: 26.11/4.16/6.58 stl/blk/tov: 0.73/0.26/3.94/ fg%/ft%/3pm: 0.49/0.92/2.03
# Josh Richardson pts/reb/ast: 13.81/3.38/3.08 stl/blk/tov: 0.94/0.71/1.90/ fg%/ft%/3pm: 0.43/0.79/1.46
# Brook Lopez pts/reb/ast: 10.98/4.46/1.56 stl/blk/tov: 0.70/2.44/1.03/ fg%/ft%/3pm: 0.43/0.81/1.38
# Shai Gilgeous-Alexander pts/reb/ast: 19.30/6.10/3.30 stl/blk/tov: 1.11/0.71/1.86/ fg%/ft%/3pm: 0.47/0.80/1.24
# John Collins pts/reb/ast: 21.59/10.15/1.46 stl/blk/tov: 0.76/1.61/1.83/ fg%/ft%/3pm: 0.58/0.80/1.44
# Trae Young pts/reb/ast: 29.63/4.25/9.33 stl/blk/tov: 1.08/0.13/4.82/ fg%/ft%/3pm: 0.44/0.86/3.42
# Robert Covington pts/reb/ast: 12.81/6.40/1.19 stl/blk/tov: 1.53/1.29/1.50/ fg%/ft%/3pm: 0.43/0.80/2.39
# Marcus Smart pts/reb/ast: 13.47/3.85/4.85 stl/blk/tov: 1.62/0.51/1.68/ fg%/ft%/3pm: 0.38/0.83/2.42
# Mike Conley pts/reb/ast: 13.83/3.24/4.34 stl/blk/tov: 0.76/0.10/1.85/ fg%/ft%/3pm: 0.41/0.79/1.95
# Karl-Anthony Towns pts/reb/ast: 26.46/10.80/4.37 stl/blk/tov: 0.94/1.20/3.14/ fg%/ft%/3pm: 0.51/0.80/3.26
# Clint Capela pts/reb/ast: 13.92/13.77/1.23 stl/blk/tov: 0.85/1.85/1.62/ fg%/ft%/3pm: 0.63/0.53/0.00
#
# Rudy Gobert pts/reb/ast: 15.06/13.71/1.50 stl/blk/tov: 0.76/1.98/1.94/ fg%/ft%/3pm: 0.70/0.62/0.00
# Draymond Green pts/reb/ast: 8.02/6.19/6.19 stl/blk/tov: 1.37/0.77/2.28/ fg%/ft%/3pm: 0.39/0.76/0.84
# LeBron James pts/reb/ast: 25.73/7.88/10.60 stl/blk/tov: 1.23/0.50/3.98/ fg%/ft%/3pm: 0.50/0.70/2.22
# Dejounte Murray pts/reb/ast: 10.67/5.78/4.09 stl/blk/tov: 1.72/0.28/1.86/ fg%/ft%/3pm: 0.47/0.80/0.59
# Derrick Favors pts/reb/ast: 9.22/9.89/1.67 stl/blk/tov: 0.56/0.98/1.13/ fg%/ft%/3pm: 0.62/0.58/0.02
# De'Aaron Fox pts/reb/ast: 20.44/4.02/6.76 stl/blk/tov: 1.42/0.51/3.13/ fg%/ft%/3pm: 0.48/0.70/1.04
# Marquese Chriss pts/reb/ast: 9.29/6.19/1.93 stl/blk/tov: 0.66/1.05/1.32/ fg%/ft%/3pm: 0.55/0.77/0.14
# Mitchell Robinson pts/reb/ast: 9.67/7.02/0.59 stl/blk/tov: 0.85/1.95/0.61/ fg%/ft%/3pm: 0.74/0.57/0.00
# Ben Simmons pts/reb/ast: 16.70/7.83/8.19 stl/blk/tov: 2.13/0.59/3.56/ fg%/ft%/3pm: 0.59/0.63/0.04
# Elfrid Payton pts/reb/ast: 9.98/4.71/7.18 stl/blk/tov: 1.56/0.38/2.13/ fg%/ft%/3pm: 0.44/0.57/0.31
# Eric Bledsoe pts/reb/ast: 15.45/4.62/5.39 stl/blk/tov: 0.95/0.45/2.50/ fg%/ft%/3pm: 0.48/0.81/1.25
# Kevin Durant pts/reb/ast: 25.99/6.37/5.86 stl/blk/tov: 0.74/1.08/2.88/ fg%/ft%/3pm: 0.52/0.89/1.76
# John Wall pts/reb/ast: 20.72/3.62/8.72 stl/blk/tov: 1.53/0.91/3.78/ fg%/ft%/3pm: 0.44/0.70/1.59
#
# Luka Doncic pts/reb/ast: 28.69/9.30/8.70 stl/blk/tov: 1.09/0.19/4.20/ fg%/ft%/3pm: 0.46/0.75/2.89
# Tobias Harris pts/reb/ast: 19.37/6.77/3.15 stl/blk/tov: 0.75/0.54/1.49/ fg%/ft%/3pm: 0.47/0.81/1.80
# Myles Turner pts/reb/ast: 11.84/6.55/1.11 stl/blk/tov: 0.76/2.18/1.24/ fg%/ft%/3pm: 0.45/0.75/1.40
# Zach LaVine pts/reb/ast: 25.50/4.82/4.23 stl/blk/tov: 1.47/0.47/3.43/ fg%/ft%/3pm: 0.45/0.80/3.07
# Devonte' Graham pts/reb/ast: 18.17/3.37/7.48 stl/blk/tov: 0.98/0.24/2.87/ fg%/ft%/3pm: 0.38/0.82/3.46
# Will Barton pts/reb/ast: 15.07/6.29/3.66 stl/blk/tov: 1.05/0.50/1.52/ fg%/ft%/3pm: 0.45/0.77/1.86
# Davis Bertans pts/reb/ast: 15.44/4.54/1.70 stl/blk/tov: 0.69/0.61/1.09/ fg%/ft%/3pm: 0.43/0.85/3.70
# Jaren Jackson Jr. pts/reb/ast: 16.93/4.70/1.41 stl/blk/tov: 0.67/1.61/1.74/ fg%/ft%/3pm: 0.47/0.74/2.50
# Nerlens Noel pts/reb/ast: 7.71/4.93/0.96 stl/blk/tov: 1.02/1.49/0.98/ fg%/ft%/3pm: 0.69/0.77/0.02
# Richaun Holmes pts/reb/ast: 12.82/8.33/1.00 stl/blk/tov: 1.00/1.41/1.26/ fg%/ft%/3pm: 0.65/0.80/0.00
# Kelly Oubre Jr. pts/reb/ast: 18.68/6.45/1.52 stl/blk/tov: 1.27/0.71/1.48/ fg%/ft%/3pm: 0.45/0.78/1.93
# Norman Powell pts/reb/ast: 16.39/3.66/1.77 stl/blk/tov: 1.25/0.39/1.45/ fg%/ft%/3pm: 0.50/0.84/2.14
# Jonathan Isaac pts/reb/ast: 12.00/6.94/1.38 stl/blk/tov: 1.56/2.44/1.47/ fg%/ft%/3pm: 0.46/0.77/0.94
#
# James Harden pts/reb/ast: 34.36/6.36/7.38 stl/blk/tov: 1.74/0.87/4.46/ fg%/ft%/3pm: 0.44/0.86/4.44
# Nikola Vucevic pts/reb/ast: 19.48/11.04/3.74 stl/blk/tov: 0.85/0.87/1.43/ fg%/ft%/3pm: 0.47/0.78/1.52
# Jrue Holiday pts/reb/ast: 19.56/4.87/6.87 stl/blk/tov: 1.67/0.80/2.87/ fg%/ft%/3pm: 0.45/0.70/2.09
# D'Angelo Russell pts/reb/ast: 23.09/3.93/6.33 stl/blk/tov: 1.07/0.29/3.27/ fg%/ft%/3pm: 0.43/0.81/3.51
# Kyle Lowry pts/reb/ast: 19.73/4.83/7.67 stl/blk/tov: 1.35/0.42/2.96/ fg%/ft%/3pm: 0.42/0.86/2.94
# DeAndre Jordan pts/reb/ast: 8.30/10.02/1.88 stl/blk/tov: 0.32/0.93/1.32/ fg%/ft%/3pm: 0.67/0.68/0.00
# T.J. Warren pts/reb/ast: 18.69/3.97/1.43 stl/blk/tov: 1.15/0.44/1.26/ fg%/ft%/3pm: 0.53/0.81/1.13
# Fred VanVleet pts/reb/ast: 17.60/3.75/6.60 stl/blk/tov: 1.90/0.27/2.29/ fg%/ft%/3pm: 0.41/0.84/2.73
# Marcus Morris Sr. pts/reb/ast: 17.36/5.11/1.40 stl/blk/tov: 0.76/0.49/1.60/ fg%/ft%/3pm: 0.43/0.82/2.42
# Collin Sexton pts/reb/ast: 20.75/3.14/2.95 stl/blk/tov: 1.00/0.11/2.43/ fg%/ft%/3pm: 0.47/0.85/1.49
# Serge Ibaka pts/reb/ast: 16.02/8.28/1.46 stl/blk/tov: 0.48/0.84/2.00/ fg%/ft%/3pm: 0.52/0.75/1.32
# Caris LeVert pts/reb/ast: 17.74/4.08/4.08 stl/blk/tov: 1.13/0.18/2.51/ fg%/ft%/3pm: 0.41/0.72/1.85
# Tristan Thompson pts/reb/ast: 12.00/10.12/2.11 stl/blk/tov: 0.58/0.88/1.81/ fg%/ft%/3pm: 0.51/0.61/0.16
#
# Giannis Antetokounmpo pts/reb/ast: 29.65/13.74/5.77 stl/blk/tov: 1.04/1.02/3.67/ fg%/ft%/3pm: 0.55/0.63/1.46
# Jimmy Butler pts/reb/ast: 20.24/6.65/6.13 stl/blk/tov: 1.70/0.54/2.19/ fg%/ft%/3pm: 0.45/0.83/0.54
# Kevin Love pts/reb/ast: 17.62/9.77/3.18 stl/blk/tov: 0.59/0.34/2.50/ fg%/ft%/3pm: 0.45/0.85/2.61
# Steven Adams pts/reb/ast: 10.91/9.36/2.43 stl/blk/tov: 0.86/1.12/1.48/ fg%/ft%/3pm: 0.59/0.59/0.02
# DeMar DeRozan pts/reb/ast: 22.16/5.64/5.57 stl/blk/tov: 1.02/0.23/2.41/ fg%/ft%/3pm: 0.53/0.84/0.13
# Lonzo Ball pts/reb/ast: 12.41/6.21/7.00 stl/blk/tov: 1.43/0.54/3.07/ fg%/ft%/3pm: 0.41/0.57/2.48
# Jonas Valanciunas pts/reb/ast: 14.87/11.23/1.76 stl/blk/tov: 0.40/1.11/1.73/ fg%/ft%/3pm: 0.59/0.73/0.47
# Christian Wood pts/reb/ast: 13.06/6.29/0.97 stl/blk/tov: 0.55/0.87/1.35/ fg%/ft%/3pm: 0.57/0.74/0.87
# Mikal Bridges pts/reb/ast: 8.69/3.98/1.77 stl/blk/tov: 1.43/0.60/1.00/ fg%/ft%/3pm: 0.52/0.85/0.86
# Goran Dragic pts/reb/ast: 16.07/3.07/5.06 stl/blk/tov: 0.57/0.15/2.46/ fg%/ft%/3pm: 0.44/0.77/2.19
# Thaddeus Young pts/reb/ast: 10.30/4.92/1.83 stl/blk/tov: 1.44/0.36/1.59/ fg%/ft%/3pm: 0.45/0.58/1.23
# Eric Paschall pts/reb/ast: 13.95/4.58/2.12 stl/blk/tov: 0.53/0.22/1.57/ fg%/ft%/3pm: 0.50/0.77/0.62
# Gary Harris pts/reb/ast: 10.38/2.91/2.11 stl/blk/tov: 1.36/0.25/1.07/ fg%/ft%/3pm: 0.42/0.82/1.25
#
# Anthony Davis pts/reb/ast: 26.67/9.40/3.13 stl/blk/tov: 1.49/2.44/2.45/ fg%/ft%/3pm: 0.51/0.84/1.18
# Deandre Ayton pts/reb/ast: 19.00/12.00/1.90 stl/blk/tov: 0.73/1.70/2.37/ fg%/ft%/3pm: 0.55/0.77/0.00
# Julius Randle pts/reb/ast: 19.50/9.72/3.09 stl/blk/tov: 0.80/0.34/3.02/ fg%/ft%/3pm: 0.46/0.73/1.00
# Donovan Mitchell pts/reb/ast: 24.21/4.38/4.19 stl/blk/tov: 1.05/0.19/2.65/ fg%/ft%/3pm: 0.45/0.86/2.48
# CJ McCollum pts/reb/ast: 22.50/4.10/4.32 stl/blk/tov: 0.74/0.63/1.87/ fg%/ft%/3pm: 0.45/0.75/2.81
# Gordon Hayward pts/reb/ast: 17.29/6.53/4.11 stl/blk/tov: 0.78/0.44/1.76/ fg%/ft%/3pm: 0.50/0.85/1.64
# Brandon Ingram pts/reb/ast: 24.25/6.25/4.30 stl/blk/tov: 1.00/0.66/3.11/ fg%/ft%/3pm: 0.47/0.86/2.45
# Wendell Carter Jr. pts/reb/ast: 11.26/9.42/1.19 stl/blk/tov: 0.77/0.84/1.67/ fg%/ft%/3pm: 0.53/0.74/0.14
# Daniel Theis pts/reb/ast: 9.29/6.55/1.64 stl/blk/tov: 0.60/1.29/0.83/ fg%/ft%/3pm: 0.57/0.76/0.45
# OG Anunoby pts/reb/ast: 10.71/5.41/1.57 stl/blk/tov: 1.40/0.67/1.19/ fg%/ft%/3pm: 0.51/0.69/1.30
# Trevor Ariza pts/reb/ast: 7.98/4.64/1.72 stl/blk/tov: 1.30/0.28/1.06/ fg%/ft%/3pm: 0.44/0.84/1.45
# Lauri Markkanen pts/reb/ast: 14.74/6.26/1.48 stl/blk/tov: 0.84/0.46/1.62/ fg%/ft%/3pm: 0.42/0.82/2.18
# Shaquille Harrison pts/reb/ast: 4.98/2.05/1.17 stl/blk/tov: 0.81/0.45/0.45/ fg%/ft%/3pm: 0.47/0.78/0.38
#
# Pascal Siakam pts/reb/ast: 23.64/7.53/3.60 stl/blk/tov: 1.00/0.92/2.49/ fg%/ft%/3pm: 0.46/0.80/2.17
# LaMarcus Aldridge pts/reb/ast: 18.89/7.40/2.43 stl/blk/tov: 0.68/1.64/1.40/ fg%/ft%/3pm: 0.49/0.83/1.15
# Terry Rozier pts/reb/ast: 18.00/4.38/4.11 stl/blk/tov: 0.97/0.16/2.24/ fg%/ft%/3pm: 0.42/0.87/2.73
# Andrew Wiggins pts/reb/ast: 21.76/5.07/3.67 stl/blk/tov: 0.83/0.98/2.44/ fg%/ft%/3pm: 0.45/0.71/2.06
# Joe Ingles pts/reb/ast: 9.75/4.00/5.17 stl/blk/tov: 0.89/0.14/1.94/ fg%/ft%/3pm: 0.44/0.77/1.92
# Kyrie Irving pts/reb/ast: 27.40/5.15/6.40 stl/blk/tov: 1.35/0.50/2.60/ fg%/ft%/3pm: 0.48/0.92/2.80
# Victor Oladipo pts/reb/ast: 13.77/3.15/3.00 stl/blk/tov: 0.85/0.23/2.15/ fg%/ft%/3pm: 0.39/0.78/1.62
# Markelle Fultz pts/reb/ast: 12.06/3.33/5.22 stl/blk/tov: 1.30/0.16/2.05/ fg%/ft%/3pm: 0.47/0.72/0.47
# Tomas Satoransky pts/reb/ast: 9.91/3.91/5.45 stl/blk/tov: 1.23/0.11/2.00/ fg%/ft%/3pm: 0.43/0.88/0.98
# Kemba Walker pts/reb/ast: 21.20/4.08/4.94 stl/blk/tov: 0.94/0.50/2.14/ fg%/ft%/3pm: 0.42/0.87/3.30
# Bam Adebayo pts/reb/ast: 16.20/10.51/5.12 stl/blk/tov: 1.20/1.31/2.85/ fg%/ft%/3pm: 0.57/0.69/0.02
# Montrezl Harrell pts/reb/ast: 18.62/7.08/1.70 stl/blk/tov: 0.62/1.14/1.71/ fg%/ft%/3pm: 0.58/0.66/0.00
#  pts/reb/ast: 0.00/0.00/0.00 stl/blk/tov: 0.00/0.00/0.00/ fg%/ft%/3pm: 0.00/0.00/0.00
#
# Joel Embiid pts/reb/ast: 23.43/11.82/3.11 stl/blk/tov: 0.86/1.32/3.07/ fg%/ft%/3pm: 0.47/0.81/1.27
# Andre Drummond pts/reb/ast: 17.72/15.16/2.67 stl/blk/tov: 1.91/1.63/3.56/ fg%/ft%/3pm: 0.53/0.57/0.09
# Zion Williamson pts/reb/ast: 23.58/6.79/2.16 stl/blk/tov: 0.84/0.47/2.68/ fg%/ft%/3pm: 0.59/0.64/0.32
# Jayson Tatum pts/reb/ast: 23.56/7.08/2.95 stl/blk/tov: 1.41/0.90/2.24/ fg%/ft%/3pm: 0.45/0.81/2.83
# Chris Paul pts/reb/ast: 17.68/4.92/6.76 stl/blk/tov: 1.56/0.14/2.17/ fg%/ft%/3pm: 0.49/0.90/1.60
# Bojan Bogdanovic pts/reb/ast: 20.24/4.11/2.08 stl/blk/tov: 0.54/0.11/2.52/ fg%/ft%/3pm: 0.45/0.90/3.00
# Spencer Dinwiddie pts/reb/ast: 20.59/3.45/6.75 stl/blk/tov: 0.62/0.33/2.72/ fg%/ft%/3pm: 0.42/0.78/1.92
# Aaron Gordon pts/reb/ast: 14.36/7.60/3.71 stl/blk/tov: 0.86/0.62/1.62/ fg%/ft%/3pm: 0.43/0.67/1.17
# Jaylen Brown pts/reb/ast: 20.44/6.36/2.18 stl/blk/tov: 1.12/0.32/2.32/ fg%/ft%/3pm: 0.49/0.74/2.14
# Harrison Barnes pts/reb/ast: 14.70/4.78/2.38 stl/blk/tov: 0.59/0.16/1.25/ fg%/ft%/3pm: 0.46/0.80/1.45
# Russell Westbrook pts/reb/ast: 27.47/8.04/6.98 stl/blk/tov: 1.66/0.32/4.45/ fg%/ft%/3pm: 0.47/0.78/0.96
# Carmelo Anthony pts/reb/ast: 15.26/6.26/1.58 stl/blk/tov: 0.80/0.46/1.74/ fg%/ft%/3pm: 0.43/0.84/1.44
# Kevin Huerter pts/reb/ast: 12.21/4.07/3.82 stl/blk/tov: 0.91/0.48/1.55/ fg%/ft%/3pm: 0.41/0.83/2.27

# %%
def parse_html_table(table):
            n_columns = 0
            n_rows=0
            column_names = []
    
            # Find number of rows and columns
            # we also find the column titles if we can
            for row in table.find_all('tr'):
                
                # Determine the number of rows in the table
                td_tags = row.find_all('td')
                if len(td_tags) > 0:
                    n_rows+=1
                    if n_columns == 0:
                        # Set the number of columns for our table
                        n_columns = len(td_tags)
                        
                # Handle column names if we find them
                th_tags = row.find_all('th') 
                if len(th_tags) > 0 and len(column_names) == 0:
                    for th in th_tags:
                        column_names.append(th.get_text())
    
            # Safeguard on Column Titles
            if len(column_names) > 0 and len(column_names) != n_columns:
                raise Exception("Column titles do not match the number of columns")
    
            columns = column_names if len(column_names) > 0 else range(0,n_columns)
            df = pd.DataFrame(columns = columns,
                              index= range(0,n_rows))
            row_marker = 0
            for row in table.find_all('tr'):
                column_marker = 0
                columns = row.find_all('td')
                for column in columns:
                    df.iat[row_marker,column_marker] = column.get_text()
                    column_marker += 1
                if len(columns) > 0:
                    row_marker += 1
                    
            # Convert to float if possible
            for col in df:
                try:
                    df[col] = df[col].astype(float)
                except ValueError:
                    pass
            
            return df

# %%
def getHashtagTable():
    url = 'https://hashtagbasketball.com/fantasy-basketball-rankings'
    url_get = requests.get(url)
    soup = BeautifulSoup(url_get.content, 'lxml')
    table = soup.find_all('table')[2]
    table = parse_html_table(table)
    table = table.replace(r'\n',' ', regex=True)
    hashtag_table = table.replace(r'\r',' ', regex=True)
    hashtag_table.set_index("PLAYER", inplace = True)
    return hashtag_table

# %%
def getBBRTable():
    url = 'https://www.basketball-reference.com/leagues/NBA_2020_per_game.html'
    url_get = requests.get(url)
    soup = BeautifulSoup(url_get.content, 'lxml')
    headers = [th.getText() for th in soup.findAll('tr', limit=2)[0].findAll('th')]
    headers = headers[1:]
    rows = soup.findAll('tr')[1:]
    player_stats = [[td.getText() for td in rows[i].findAll('td')]
                for i in range(len(rows))]
    bbr_table = pd.DataFrame(player_stats, columns = headers)
    bbr_table.set_index("Player", inplace = True)
#     bbr_table.head(10)
    return bbr_table

# %%
def getBBMTable():
    url = 'https://basketballmonster.com/playerrankings.aspx'
    url_get = requests.get(url)
    # time.sleep(1)
    soup = BeautifulSoup(url_get.content, 'lxml')
    table = soup.find_all('table')[0]
    bbm_table = parse_html_table(table)
    bbm_table.set_index("Name", inplace = True)
    return bbm_table

# %%
def getRosters(leagueID):
    url = 'https://fantasy.espn.com/basketball/team?leagueId=' + str(leagueID) + '&teamId='
    # url = 'https://fantasy.espn.com/basketball/team?leagueId=65116266&teamId='
    # data = call_espn_api(65116266)
    # print(data)
    webdriver = "C:\Downloads\chromedriver_win32\chromedriver.exe"
    driver = Chrome(webdriver)
    all_teams = [[0 for i in range(13)] for j in range(10)]
    for i in range(1, 11):
        curr = url + str(i)
        driver.get(curr)
        time.sleep(4)
        html = driver.page_source
        soup = BeautifulSoup(html, 'html.parser')
        table = soup.find_all('table')[0]
        player_list = table.find_all('img')
        players = set()
        for player in player_list:
            if player.get('alt') != '':
                players.add(player.get('alt'))
        all_teams[i-1] = list(players)
    return all_teams

# %%
def genNameMapping(all_teams):
    name_mapping = {}
    name_mapping["Kristaps Porzingis"] = "Kristaps Porziņģis"
    name_mapping["Nikola Jokic"] = "Nikola Jokić"
    name_mapping["Nikola Vucevic"] = "Nikola Vučević"
    name_mapping["Taurean Prince"] = "Taurean Waller-Prince"
    name_mapping["Marvin Bagley III"] = "Marvin Bagley"
    name_mapping["Wendell Carter Jr."] = "Wendell Carter"
    name_mapping["Jonas Valanciunas"] = "Jonas Valančiūnas"
    name_mapping["Luka Doncic"] = "Luka Dončić"
    name_mapping["Jaren Jackson Jr."] = "Jaren Jackson"
    name_mapping["Davis Bertans"] = "Dāvis Bertāns"
    name_mapping["PJ Tucker"] = "P.J. Tucker"
    name_mapping["PJ Washington"] = "P.J. Washington"
    name_mapping["Marcus Morris Sr."] = "Marcus Morris"
    name_mapping["Tomas Satoransky"] = "Tomáš Satoranský"
    name_mapping["JJ Redick"] = "J.J. Redick"
    name_mapping["Kelly Oubre Jr."] = "Kelly Oubre"
    name_mapping["Dennis Schroder"] = "Dennis Schröder"
    name_mapping["Bojan Bogdanovic"] = "Bojan Bogdanović"
    name_mapping["Bogdan Bogdanovic"] = "Bogdan Bogdanović"
    name_mapping["Goran Dragic"] = "Goran Dragić"
    name_mapping["Gary Payton II"] = "Gary Payton"
    name_mapping["Jakob Poeltl"] = "Jakob Pöltl"
    name_mapping["Michael Porter Jr."] = "Michael Porter"
    name_mapping["Larry Nance Jr."] = "Larry Nance"
    return name_mapping
def genTeamMapping():
    team_map = {}
    team_map['janav'] = 0
    team_map['elliot'] = 1
    team_map['calvin'] = 2
    team_map['karthik'] = 3
    team_map['eric'] = 4
    team_map['garrett'] = 5
    team_map['nikhil'] = 6
    team_map['risit'] = 7
    team_map['aj'] = 8
    team_map['norman'] = 9
    return team_map

# %%
def addTeamData(df, label, rosters, name_mapping):
    team_data = [0 for j in range(10)]
    for i in range(0, 10):
        val = 0
        for j in range(0, len(rosters[i])):
            name = rosters[i][j]
            if name not in df.index:
                if name in name_mapping.keys():
                    name = name_mapping[name]
                if name not in df.index:
                    print("missing" + name)
                    continue
            row = df.loc[name]
            if len(row) == 3:
                row = row.loc[row['Tm'] == 'TOT']
            val += float(row[label])
        team_data[i] = val
    return team_data
def addTeamDataHashtag(df, label, rosters, name_mapping):
    team_data = [0 for j in range(10)]
    for i in range(0, 10):
        val = 0
        for j in range(0, len(rosters[i])):
            name = " " + rosters[i][j] + " "
            if name == " PJ Tucker ":
                name = " P.J. Tucker "
            elif name == " PJ Washington ":
                name = " P.J. Washington "
            if name not in df['TOTAL']:
                name = name + " "
                if name not in df['TOTAL']:
                    continue
            row = df.loc[name]
            val += float(row[label])
        team_data[i] = val
    return team_data
def rank_list(input, order):
    output = [0] * len(input)
    for i, x in enumerate(sorted(range(len(input)), key=lambda y: order *input[y])):
        output[x] = i + 1
    return output
def genRankTable(all_teams, name_mapping, hashtag_table, bbr_table, teamList):
    fga = addTeamData(bbr_table, 'FGA', all_teams, name_mapping)
    fgm = addTeamData(bbr_table, 'FG', all_teams, name_mapping)
    fg = [rank_list([fgm[i]/fga[i] for i in range(0, len(fga))], -1)]
    fta = addTeamData(bbr_table, 'FTA', all_teams, name_mapping)
    ftm = addTeamData(bbr_table, 'FT', all_teams, name_mapping)
    ft = [rank_list([ftm[i]/fta[i] for i in range(0, len(fta))], -1)]
#     points = [rank_list(addTeamDataHashtag(hashtag_table, 'PTS', all_teams, name_mapping), -1)]
#     rebounds = [rank_list(addTeamDataHashtag(hashtag_table, 'TREB', all_teams, name_mapping), -1)]
#     assists = [rank_list(addTeamDataHashtag(hashtag_table, 'AST', all_teams, name_mapping), -1)]
#     steals = [rank_list(addTeamDataHashtag(hashtag_table, 'STL', all_teams, name_mapping), -1)]
#     blocks = [rank_list(addTeamDataHashtag(hashtag_table, 'BLK', all_teams, name_mapping), -1)]
#     turnovers = [rank_list(addTeamDataHashtag(hashtag_table, 'TO', all_teams, name_mapping), 1)]
#     threes = [rank_list(addTeamDataHashtag(hashtag_table, '3PM', all_teams, name_mapping), -1)]
    points = [rank_list(addTeamData(bbr_table, 'PTS', all_teams, name_mapping), -1)]
    rebounds = [rank_list(addTeamData(bbr_table, 'TRB', all_teams, name_mapping), -1)]
    assists = [rank_list(addTeamData(bbr_table, 'AST', all_teams, name_mapping), -1)]
    steals = [rank_list(addTeamData(bbr_table, 'STL', all_teams, name_mapping), -1)]
    blocks = [rank_list(addTeamData(bbr_table, 'BLK', all_teams, name_mapping), -1)]
    turnovers = [rank_list(addTeamData(bbr_table, 'TOV', all_teams, name_mapping), 1)]
    threes = [rank_list(addTeamData(bbr_table, '3P', all_teams, name_mapping), -1)]
    # total = [rankList(addTeamDataHashtag(hashtag_table, 'TOTAL', all_teams, name_mapping), -1)]
    data = [*zip(*(fg + ft + points + rebounds + assists + steals + blocks + turnovers + threes))]
    rank_table = pd.DataFrame(data, index = teamList, columns = ['fg%', 'ft%', 'points','rebounds','assists','steals','blocks','turnovers','threes'])
    rank_table["Total"] = rank_table.sum(axis = 1, skipna = True)
    return rank_table
def genStatsTable(all_teams, name_mapping, hashtag_table, bbr_table, teamList):
    fga = addTeamData(bbr_table, 'FGA', all_teams, name_mapping)
    fgm = addTeamData(bbr_table, 'FG', all_teams, name_mapping)
    fg = [[fgm[i]/fga[i] for i in range(0, len(fga))]]
    fta = addTeamData(bbr_table, 'FTA', all_teams, name_mapping)
    ftm = addTeamData(bbr_table, 'FT', all_teams, name_mapping)
    ft = [[ftm[i]/fta[i] for i in range(0, len(fta))]]
#     points = [addTeamDataHashtag(hashtag_table, 'PTS', all_teams, name_mapping)]
#     rebounds = [addTeamDataHashtag(hashtag_table, 'TRB', all_teams, name_mapping)]
#     assists = [addTeamDataHashtag(hashtag_table, 'AST', all_teams, name_mapping)]
#     steals = [addTeamDataHashtag(hashtag_table, 'STL', all_teams, name_mapping)]
#     blocks = [addTeamDataHashtag(hashtag_table, 'BLK', all_teams, name_mapping)]
#     turnovers = [addTeamDataHashtag(hashtag_table, 'TO', all_teams, name_mapping)]
#     threes = [addTeamDataHashtag(hashtag_table, '3PM', all_teams, name_mapping)]
    points = [addTeamData(bbr_table, 'PTS', all_teams, name_mapping)]
    rebounds = [addTeamData(bbr_table, 'TRB', all_teams, name_mapping)]
    assists = [addTeamData(bbr_table, 'AST', all_teams, name_mapping)]
    steals = [addTeamData(bbr_table, 'STL', all_teams, name_mapping)]
    blocks = [addTeamData(bbr_table, 'BLK', all_teams, name_mapping)]
    turnovers = [addTeamData(bbr_table, 'TOV', all_teams, name_mapping)]
    threes = [addTeamData(bbr_table, '3P', all_teams, name_mapping)]
    # total = [rankList(addTeamDataHashtag(hashtag_table, 'TOTAL', all_teams, name_mapping), -1)]
    data = [*zip(*(fg + ft + points + rebounds + assists + steals + blocks + turnovers + threes))]
    stats_table = pd.DataFrame(data, index = teamList, columns = ['fg%', 'ft%', 'points','rebounds','assists','steals','blocks','turnovers','threes'])
    return stats_table

# %%
def calculate_matchups(team_name, rank_table):
    my_team = rank_table.loc[team_name]
    would_beat = []
    would_lose = []
    overall_margin = []
    for i in range(10):
        margin = []
        score = 0
        curr_team = rank_table.iloc[i]
        if curr_team.name == my_team.name:
            continue
        for j in range(9):
            if my_team.iloc[j] < curr_team.iloc[j]:
                score += 1
                margin.append(curr_team.iloc[j] - my_team.iloc[j])
        if score >= 5:
            would_beat.append(curr_team.name)
        else:
            would_lose.append(curr_team.name)
        avg = sum(margin)/len(margin)
#         print(my_team.name + " " + str(score) + " " + curr_team.name + " " + str(9 - score) + " by an average of " + str(avg))
    return would_beat, would_lose

# %%
def genRankList(table):
    num_beaten = [0 for i in range(0, table.shape[0])]
    teams = table.index
    matchups = [[0 for i in range(2)]for i in range(0, table.shape[0])]
    for i in range(len(teams)):
        beats, loses = calculate_matchups(teams[i],table)
        num_beaten[i] = len(beats)
        beats_str = " "
        for j in range(len(beats)):
            beats_str += beats[j] + ", "
        loses_str = " "
        for j in range(len(loses)):
            loses_str += loses[j] + ", "
#         print(teams[i] + " beats" + beats_str + "and loses to" + loses_str)
#         print("")
        matchups[i][0] = beats
        matchups[i][1] = loses
    return rank_list(num_beaten, -1), matchups

# %%
def printRow(df, index):
    df = {x: y for x, y in zip(df.columns, df.loc[index])}
    sf = pd.DataFrame(df, index=[index])
    display(sf)

# %%
def trade_analyzer(rosters, team1, team2, players_from1, players_from2, refresh, hashtagTable, bbrTable):
    if len(players_from1) != len(players_from2):
        print("The number of players exchanged must be equal")
    name_mapping = genNameMapping(rosters)
    if (refresh == 1):
        hashtagTable, bbrTable, bbmTable, rosters = refreshData(65116266)
    for player in players_from1:
        if player not in bbrTable.index:
            player = name_mapping[player]
        printRow(bbrTable, player)
    for player in players_from2:
        if player not in bbrTable.index:
            player = name_mapping[player]
        printRow(bbrTable, player)
    old_data = genRankTable(rosters, name_mapping, hashtagTable, bbrTable, team_map.keys())
    old_stats = genRankTable(rosters, name_mapping, hashtagTable, bbrTable, team_map.keys())
    old_rankList, matchups = genRankList(old_data)
    print("Prior to the trade " + team1 + " was ranked "+ str(old_rankList[team_map[team1]]))
    printRow(old_data, team1)
    print("Prior to the trade " + team2 + " was ranked "+ str(old_rankList[team_map[team2]]))
    printRow(old_data, team2)
    new_team1 = [player for player in rosters[team_map[team1]] if player not in players_from1] + players_from2
    new_team2 = [player for player in rosters[team_map[team2]] if player not in players_from2] + players_from1
    new_rosters =[[j for j in i] for i in rosters]
    new_rosters[team_map[team1]] = new_team1
    new_rosters[team_map[team2]] = new_team2
    new_data = genRankTable(new_rosters, name_mapping, hashtagTable, bbrTable, team_map.keys())
    new_rankList, matchups = genRankList(new_data)
    print("After the trade " + team1 + " was ranked "+ str(new_rankList[team_map[team1]]))
    printRow(new_data, team1)
    print("After the trade " + team2 + " was ranked "+ str(new_rankList[team_map[team2]]))
    printRow(new_data, team2)
#     waiver_analyzer(new_rosters, "eric", ["Kris Dunn"], ["Chris Boucher"], hashtagTable, bbrTable)

    
    
def waiver_analyzer(rosters, team, players_in, players_out, hashtagTable, bbrTable):
    if len(players_in) != len(players_out):
        print("The number of players exchanged must be equal")
    name_mapping = genNameMapping(rosters)
    for player in players_in:
        if player not in bbrTable.index:
            player = name_mapping[player]
        printRow(bbrTable, player)
    for player in players_out:
        if player not in bbrTable.index:
            player = name_mapping[player]
        printRow(bbrTable, player)
    team_map = genTeamMapping()
    old_data = genRankTable(rosters, name_mapping, hashtagTable, bbrTable, team_map.keys())
    old_rankList, matchups = genRankList(old_data)
    print("Prior to the pickup " + team + " was ranked "+ str(old_rankList[team_map[team]]))
    printRow(old_data, team)
    print(matchups[team_map[team]])
    new_team = [player for player in rosters[team_map[team]] if player not in players_out] + players_in
    new_rosters =[[j for j in i] for i in rosters]
    new_rosters[team_map[team]] = new_team
    new_data = genRankTable(new_rosters, name_mapping, hashtagTable, bbrTable, team_map.keys())
    new_data = genRankTable(new_rosters, name_mapping, hashtagTable, bbrTable, team_map.keys())
    new_rankList, matchups= genRankList(new_data)
    print("After the pickup " + team + " was ranked "+ str(new_rankList[team_map[team]]))
    print(matchups[team_map[team]])
    printRow(new_data, team)

# %%
def refreshData(leagueID):
    hashtagTable = getHashtagTable()
    bbrTable = getBBRTable()
    bbmTable = getBBMTable()
    rosters = getRosters(leagueID)
    return hashtagTable, bbrTable, bbmTable, rosters
hashtagTable, bbrTable, bbmTable, rosters = refreshData(65116266)

# %%
def getWorstPlayer(rankings, player_list, rosters):
    worst = ""
    worstRank = 0
    name_mapping = genNameMapping(rosters)
    for player in player_list:
        if player not in rankings.index:
            player = " " + name_mapping[player] + " "
        if int(rankings.loc[player]["R#"].strip()) > worstRank:
            worst = player
            worstRank = rankings.loc[player]["R#"]
    return worst

# %%
def getSoup(url,sleep_time ):
    webdriver = "C:\Downloads\chromedriver_win32\chromedriver.exe"
    driver = Chrome(webdriver)
    driver.get(url)
    time.sleep(sleep_time)
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')
    return soup

# %%
def getGames(soup):
    player_table = soup.find("tbody", class_="Table2__tbody").find_all("tr", class_="Table2__tr")
    print(len(player_table))
    player_mapping = {}
    for i in range(0, len(player_table)):
        player_row = soup.find("tbody", class_="Table2__tbody").find_all("tr", class_="Table2__tr", attrs={"data-idx": str(i)})
        player_name = soup.find("tbody", class_="Table2__tbody").find("tr", class_="Table2__tr", attrs={"data-idx": str(i)}).find("td", class_= "Table2__td Table2__td--fixed-width", style = "width: 228px;").find("div")['title']
        for j in range(0,len(player_row)):
            todays_game = soup.find("tbody", class_="Table2__tbody").find("tr", class_="Table2__tr", attrs={"data-idx": str(i)}).find_all("td", class_= "Table2__td Table2__td--fixed-width", style = "width: 60px;")[1]
            todays_game = str(todays_game)
            todays_soup = BeautifulSoup(todays_game, 'html.parser')
            todays_game = todays_soup.find("div", class_="jsx-2810852873 table--cell opp ml4").getText()
#             print(todays_game)
            rest_of_games = soup.find("tbody", class_="Table2__tbody").find("tr", class_="Table2__tr", attrs={"data-idx": str(i)}).find_all("td", class_= "Table2__td", attrs={'style': None})
            game_text = ""
            for i in range(len(rest_of_games)):
                game_text = game_text + str(rest_of_games[i])
            rest_soup = BeautifulSoup(game_text, 'html.parser')
            rest_of_games = rest_soup.find_all(text=True)
            player_mapping[player_name] = [todays_game] + rest_of_games
    return player_mapping

def getAllMatchups(soup):
    soups = soup.find_all("div", class_ = "jsx-1241409305 matchup-score two-links")
    team_stats = {}
    matchups = {}
    for soup in soups:
        #get team id's and construct matchup mappings
        teams = soup.find_all("li", class_="ScoreboardScoreCell__Item")
        team1_link = BeautifulSoup(str(teams[0]), 'html.parser').find("a")['href']
        team1_id = team1_link[56:58]
        if team1_id != "10":
            team1_id = team1_id[:1]
        team2_link = BeautifulSoup(str(teams[1]), 'html.parser').find("a")['href']
        team2_id = team2_link[56:58]
        if team2_id != "10":
            team2_id = team2_id[:1]
        matchups[int(team1_id)] = int(team2_id)
        matchups[int(team2_id)] = int(team1_id)
        
        
        #get stats for each team and construct player to stats mapping
        stats_table = soup.find("table", class_ = "Table2__table-scroller Table2__table")
        categories = stats_table.find("thead").find_all("th", class_ ="Table2__th")
        temp = ""
        for i in range(len(categories)):
            temp = temp + str(categories[i])
        header_soup = BeautifulSoup(temp, 'html.parser')
        categories = header_soup.find_all(text=True)
        
        player1_stats = stats_table.find("tbody").find("tr", attrs={"data-idx": str(0)}).find_all(text=True)[1:]
        player1_stats = [float(i) for i in player1_stats]
        team_stats[team1_id] = player1_stats
        
        player2_stats = stats_table.find("tbody").find("tr", attrs={"data-idx": str(1)}).find_all(text=True)[1:]
        player2_stats = [float(i) for i in player2_stats]
        team_stats[team2_id] = player2_stats
    return matchups, team_stats, categories
def matchup_predictor(table, days, teamID, matchups, categories, team_stats):
    schedule_url = 'https://fantasy.espn.com/basketball/team?leagueId=65116266&teamId=' + str(teamID) + '&view=schedule'    
    soup = getSoup(schedule_url, 4)
    player_mapping1 = getGames(soup)
    player1_num_games = {}
    for player in player_mapping1.keys():
        player_mapping1[player] = player_mapping1[player][:days]
        player1_num_games[player] = sum([1 for game in player_mapping1[player] if game != "--"])
    schedule_url = 'https://fantasy.espn.com/basketball/team?leagueId=65116266&teamId=' + str(matchups[teamID]) + '&view=schedule'    
    soup = getSoup(schedule_url, 4)
    player_mapping2 = getGames(soup)
    print(player_mapping2)
    player2_num_games = {}
    for player in player_mapping2.keys():
        player_mapping2[player] = player_mapping2[player][:days]
        player2_num_games[player] = sum([1 for game in player_mapping2[player] if game != "--"])
    for player in player1_num_games.keys():
        for 
    
scoreboard_url = "https://fantasy.espn.com/basketball/league/scoreboard?leagueId=65116266"
# scoreboard_soup = getSoup(scoreboard_url, 4)
matchups, team_stats, categories = getAllMatchups(scoreboard_soup)
print(team_stats)
matchup_predictor(bbrTable, 1, 5, matchups, categories, team_stats)
# Out:
# {'7': [0.4548, 0.725, 33.0, 177.0, 99.0, 33.0, 10.0, 56.0, 432.0], '10': [0.4824, 0.7679, 43.0, 144.0, 96.0, 32.0, 9.0, 57.0, 457.0], '3': [0.5, 0.8915, 54.0, 161.0, 114.0, 26.0, 24.0, 62.0, 549.0], '8': [0.4432, 0.8571, 43.0, 204.0, 74.0, 24.0, 26.0, 62.0, 471.0], '9': [0.4901, 0.6887, 38.0, 189.0, 136.0, 28.0, 21.0, 77.0, 509.0], '4': [0.5249, 0.7071, 20.0, 199.0, 130.0, 38.0, 18.0, 62.0, 364.0], '1': [0.4615, 0.8468, 45.0, 218.0, 118.0, 26.0, 36.0, 63.0, 547.0], '2': [0.4614, 0.8699, 62.0, 192.0, 107.0, 25.0, 14.0, 61.0, 551.0], '5': [0.4372, 0.7303, 64.0, 145.0, 73.0, 26.0, 28.0, 48.0, 463.0], '6': [0.4516, 0.8397, 58.0, 162.0, 135.0, 41.0, 15.0, 61.0, 616.0]}
# 13
# 13
# {'Derrick Rose': ['--', 'Cle', '--', '@Bkn', '--', 'Tor', '--', 'Den'], 'James Harden': [' @Den ', '@Utah', '--', '@Por', '--', 'Dal', '--', 'NO'], 'T.J. Warren': [' @Por ', '--', '--', 'Chi', '--', '--', 'NY', '--'], 'Nemanja Bjelica': ['--', '@Min', '--', 'OKC', '@LAC', '--', 'LAL', '--'], 'Nikola Vucevic': [' LAC ', '@Mia', '--', '--', '--', '--', 'Mia', '--'], "D'Angelo Russell": ['--', '--', '@Phi', '--', '@Bos', '--', '@Cle', '--'], 'Serge Ibaka': [' @SA ', '--', 'Atl', '--', '@Cle', '@Det', '--', 'Chi'], 'Jrue Holiday': [' Bos ', '--', '@Cle', '--', '--', 'Mem', '--', '@Hou'], 'DeAndre Jordan': [' @NY ', '--', '--', 'Det', '--', 'Chi', '@Wsh', '--'], 'Collin Sexton': ['--', '@Det', 'NO', '--', 'Tor', '--', 'GS', '--'], 'Kyle Lowry': [' @SA ', '--', 'Atl', '--', '@Cle', '@Det', '--', 'Chi'], 'Fred VanVleet': [' @SA ', '--', 'Atl', '--', '@Cle', '@Det', '--', 'Chi'], 'Marcus Morris Sr.': [' Bkn ', '--', '@Cha', 'Mem', '--', '--', '@Ind', '--']}
# {'Malcolm Brogdon': 1, 'Will Barton': 1, 'Tobias Harris': 0, 'Davis Bertans': 1, 'Brandon Clarke': 1, 'Zach LaVine': 0, 'Jaren Jackson Jr.': 1, 'Myles Turner': 1, 'Richaun Holmes': 0, 'PJ Washington': 0, 'Luka Doncic': 0, "Devonte' Graham": 0, 'Nerlens Noel': 0}
# {'Derrick Rose': 0, 'James Harden': 1, 'T.J. Warren': 1, 'Nemanja Bjelica': 0, 'Nikola Vucevic': 1, "D'Angelo Russell": 0, 'Serge Ibaka': 1, 'Jrue Holiday': 1, 'DeAndre Jordan': 1, 'Collin Sexton': 0, 'Kyle Lowry': 1, 'Fred VanVleet': 1, 'Marcus Morris Sr.': 1}

# %%
name_mapping = genNameMapping(rosters)
team_map = genTeamMapping()
data = genRankTable(rosters, name_mapping, hashtagTable, bbrTable, team_map.keys())
rankList, matchups = genRankList(data)
stats_table = genStatsTable(rosters, name_mapping, hashtagTable, bbrTable, team_map.keys())
data["rank"] = rankList
display(data)
display(stats_table)
# Out:
#          fg%  ft%  points  rebounds  assists  steals  blocks  turnovers  \
# janav      7    3       6         7        5      10       4          3
# elliot     4    2       3         5        4       7      10          6
# calvin    10    1       4         9        3       4       5          7
# karthik    1   10      10         2        8       5       3          1
# eric       6    6       9         6        9       8       1          2
# garrett    8    4       2         8        2       2       7          9
# nikhil     2    9       8         1        7       6       6          5
# risit      3    5       5         4       10       9       2          4
# aj         9    7       7        10        1       1       9          8
# norman     5    8       1         3        6       3       8         10
#
#          threes  Total  rank
# janav         5     50     5
# elliot        3     44     3
# calvin        1     44     1
# karthik      10     50     6
# eric          4     51     7
# garrett       2     44     2
# nikhil        9     53     8
# risit         8     50     9
# aj            7     59    10
# norman        6     50     4
#               fg%       ft%  points  rebounds  assists  steals  blocks  \
# janav    0.462275  0.814894   216.8      75.3     46.2    10.2    10.3
# elliot   0.477654  0.830357   234.2      78.8     47.2    11.5     5.7
# calvin   0.448652  0.854043   226.1      64.1     48.9    12.6     9.4
# karthik  0.528548  0.680653   166.1      90.6     43.4    12.4    10.8
# eric     0.464923  0.800959   203.3      75.9     43.3    11.4    11.5
# garrett  0.454822  0.812854   248.7      70.3     57.0    14.1     7.1
# nikhil   0.496412  0.743219   208.2      97.1     44.0    12.1     9.1
# risit    0.489374  0.803063   219.4      89.2     37.6    11.3    10.9
# aj       0.454650  0.785047   210.1      63.6     66.2    14.7     6.0
# norman   0.469697  0.768072   257.6      89.7     45.9    13.5     6.8
#
#          turnovers  threes
# janav         25.5    23.7
# elliot        27.2    25.9
# calvin        28.6    26.6
# karthik       23.4     7.5
# eric          23.9    24.3
# garrett       30.9    26.3
# nikhil        26.7    15.0
# risit         25.5    16.7
# aj            30.0    19.4
# norman        32.0    21.2

# %%
# waiver_analyzer(rosters, "eric", ["PJ Washington"], ["Jeremy Lamb"], hashtagTable, bbrTable)
trade_analyzer(rosters, "garrett", "calvin", ['Fred VanVleet', 'D\'Angelo Russell'],["John Collins", "Shai Gilgeous-Alexander"], 0, hashtagTable, bbrTable)
# Out:
#               Pos Age   Tm   G  GS    MP   FG   FGA   FG%   3P  ...   FT%  \
# Fred VanVleet  PG  25  TOR  48  48  35.8  6.0  14.6  .409  2.7  ...  .843
#
#                ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# Fred VanVleet  0.4  3.4  3.8  6.6  1.9  0.3  2.3  2.5  17.6
#
# [1 rows x 28 columns]
#                   Pos  Age  Tm  G  GS  MP  FG  FGA  FG%  3P  ...  FT%  ORB  \
# D'Angelo Russell  Pos  Age  Tm  G  GS  MP  FG  FGA  FG%  3P  ...  FT%  ORB
#
#                   DRB  TRB  AST  STL  BLK  TOV  PF  PTS
# D'Angelo Russell  DRB  TRB  AST  STL  BLK  TOV  PF  PTS
#
# [1 rows x 28 columns]
#              Pos Age   Tm   G  GS    MP   FG   FGA   FG%   3P  ...   FT%  ORB  \
# John Collins  PF  22  ATL  33  33  32.5  8.4  14.6  .577  1.3  ...  .800  2.7
#
#               DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# John Collins  7.6  10.3  1.4  0.7  1.6  1.8  3.5  20.8
#
# [1 rows x 28 columns]
#                         Pos Age   Tm   G  GS    MP   FG   FGA   FG%   3P  ...  \
# Shai Gilgeous-Alexander  SG  21  OKC  58  58  35.5  7.0  15.0  .464  1.2  ...
#
#                           FT%  ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# Shai Gilgeous-Alexander  .809  0.8  5.6  6.3  3.3  1.1  0.7  1.9  1.7  19.4
#
# [1 rows x 28 columns]
# Prior to the trade garrett was ranked 2
#          fg%  ft%  points  rebounds  assists  steals  blocks  turnovers  \
# garrett    8    4       2         8        2       2       7          9
#
#          threes  Total
# garrett       2     44
# Prior to the trade calvin was ranked 1
#         fg%  ft%  points  rebounds  assists  steals  blocks  turnovers  \
# calvin   10    1       4         9        3       4       5          7
#
#         threes  Total
# calvin       1     44
# After the trade garrett was ranked 1
#          fg%  ft%  points  rebounds  assists  steals  blocks  turnovers  \
# garrett    5    4       2         5        3       4       6          7
#
#          threes  Total
# garrett       5     41
# After the trade calvin was ranked 2
#         fg%  ft%  points  rebounds  assists  steals  blocks  turnovers  \
# calvin   10    1       4        10        2       2       7          9
#
#         threes  Total
# calvin       1     46

# %%
# rosters[team_map["janav"]][7] = "Kendrick Nunn"
rosters[team_map["eric"]]
# Out:
# ['Davis Bertans',
#  'Jaren Jackson Jr.',
#  'Zach LaVine',
#  'Gorgui Dieng',
#  'Tobias Harris',
#  "Devonte' Graham",
#  'Nerlens Noel',
#  'Maxi Kleber',
#  'Luka Doncic',
#  'Malcolm Brogdon',
#  'Richaun Holmes',
#  'Will Barton',
#  'Myles Turner']

# %%
matchups[team_map["eric"]]
# Out:
# [['janav', 'risit', 'aj'],
#  ['elliot', 'calvin', 'karthik', 'garrett', 'nikhil', 'norman']]

# %%
bbrTable
# Out:
#                            Pos   Age    Tm     G    GS    MP    FG   FGA  \
# Player
# Steven Adams                 C    26   OKC    36    36  28.3   5.0   8.2
# Bam Adebayo                  C    22   MIA    39    39  34.3   6.1  10.2
# LaMarcus Aldridge            C    34   SAS    36    36  33.0   7.5  14.7
# Nickeil Alexander-Walker    SG    21   NOP    31     0  13.6   2.1   6.2
# Grayson Allen               SG    24   MEM    25     0  16.9   2.7   6.1
# ...                        ...   ...   ...   ...   ...   ...   ...   ...
# Trae Young                  PG    21   ATL    36    36  35.1   9.3  21.0
# Cody Zeller                  C    27   CHO    39    20  23.1   4.5   8.4
# NaN                       None  None  None  None  None  None  None  None
# Ante Žižić                   C    23   CLE    16     0   9.9   1.8   3.1
# Ivica Zubac                  C    22   LAC    40    38  17.3   3.3   5.4
#
#                            FG%    3P  ...   FT%   ORB   DRB   TRB   AST   STL  \
# Player                                ...
# Steven Adams              .614   0.0  ...  .565   3.6   6.5  10.2   2.7   0.7
# Bam Adebayo               .593   0.0  ...  .684   2.6   7.8  10.4   4.5   1.3
# LaMarcus Aldridge         .508   1.2  ...  .836   2.0   5.6   7.6   2.5   0.6
# Nickeil Alexander-Walker  .342   1.2  ...  .571   0.2   2.0   2.2   2.0   0.3
# Grayson Allen             .441   1.3  ...  .897   0.2   2.1   2.3   1.3   0.3
# ...                        ...   ...  ...   ...   ...   ...   ...   ...   ...
# Trae Young                .443   3.4  ...  .846   0.6   4.0   4.5   8.4   1.2
# Cody Zeller               .537   0.4  ...  .704   2.9   4.3   7.2   1.3   0.6
# NaN                       None  None  ...  None  None  None  None  None  None
# Ante Žižić                .571   0.0  ...  .867   0.9   2.6   3.4   0.2   0.4
# Ivica Zubac               .599   0.0  ...  .739   2.5   4.4   6.8   0.9   0.2
#
#                            BLK   TOV    PF   PTS
# Player
# Steven Adams               1.1   1.5   1.9  12.0
# Bam Adebayo                1.2   2.8   2.6  15.8
# LaMarcus Aldridge          1.8   1.4   2.3  18.9
# Nickeil Alexander-Walker   0.1   1.0   1.2   5.8
# Grayson Allen              0.0   0.9   1.3   7.7
# ...                        ...   ...   ...   ...
# Trae Young                 0.1   4.8   1.6  28.9
# Cody Zeller                0.4   1.4   2.5  11.7
# NaN                       None  None  None  None
# Ante Žižić                 0.3   0.3   1.3   4.3
# Ivica Zubac                0.9   0.9   2.4   8.2
#
# [510 rows x 28 columns]
